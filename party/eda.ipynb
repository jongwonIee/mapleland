# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from matplotlib import rc
rc('font', family='AppleGothic')

# %%
df = pd.read_csv("data/output/df.csv")
processed_df = pd.read_csv("data/output/processed_df.csv")

# %%
# Display basic information about the DataFrame
print("Basic Info:")
print(df.info())

print("\nData Overview:")
print(df.head())

# Count frequency of maps
map_counts = df["map"].value_counts()

print("\nMap Frequency:")
print(map_counts)

# Count frequency of jobs
job_counts = df["job"].value_counts()

print("\nJob Frequency:")
print(job_counts)

# Distribution of levels by job
print("\nLevel Statistics by Job:")
print(df.groupby("job")["level"].describe())

# Convert 'level' column to numeric for analysis
df["level"] = pd.to_numeric(df["level"], errors="coerce")
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2681 entries, 0 to 2680
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   party_id           2681 non-null   int64
#  1   time               2681 non-null   object
#  2   level              2644 non-null   float64
#  3   job                2681 non-null   object
#  4   spec               365 non-null    float64
#  5   map                2376 non-null   object
#  6   date               2681 non-null   object
#  7   valid              2681 non-null   bool
#  8   valid_spec         2681 non-null   bool
#  9   spec_by_level      2520 non-null   float64
#  10  avg_spec_by_level  2520 non-null   float64
#  11  spec_filled        2487 non-null   float64
# dtypes: bool(2), float64(5), int64(1), object(4)
# memory usage: 214.8+ KB
# None
#
# Data Overview:
#    party_id     time  level    job    spec  map        date  valid  \
# 0         1  오후 1:24  104.0   프리스트     NaN  물어전  2024-12-18   True
# 1         2  오후 1:24  129.0   프리스트     NaN   검켄  2024-12-18   True
# 2         3  오후 1:24  131.0     썬콜     NaN  망용둥  2024-12-18   True
# 3         4  오후 1:24  144.0     허밋     NaN  NaN  2024-12-18  False
# 4         5  오후 1:24  131.0  크루세이더  4200.0  NaN  2024-12-18  False
#
#    valid_spec  spec_by_level  avg_spec_by_level  spec_filled
# 0       False       6.212909           6.212909   646.142571
# 1       False       6.212909           6.212909   801.465304
# 2       False            NaN                NaN          NaN
# 3       False      18.275360          18.275360  2631.651779
# 4        True      32.061069          33.070390  4200.000000
#
# Map Frequency:
# map
# 협동     338
# 망용둥    283
# 불어전    283
# 듀파     234
# 블와둥    208
# 붉켄     173
# 검켄     139
# 깊바협    138
# 레와둥    109
# 산양      87
# 하둥      84
# 오징어     58
# 와협      54
# 갈림길     51
# 망둥쩔     35
# 푸켄      27
# 물어전     27
# 위둥      24
# 남둥      13
# 큰둥      11
# Name: count, dtype: int64
#
# Job Frequency:
# job
# 프리스트     705
# 허밋       546
# 썬콜       348
# 용기사      319
# 레인저      265
# 크루세이더    228
# 불독       101
# 저격수       82
# 나이트       74
# 시프        13
# Name: count, dtype: int64
#
# Level Statistics by Job:
#        count        mean        std   min     25%    50%     75%    max
# job
# 나이트     74.0  118.527027  18.918153  80.0  106.25  120.0  131.75  157.0
# 레인저    253.0  123.075099  18.699543  84.0  109.00  123.0  135.00  173.0
# 불독      99.0  132.101010  19.567515  87.0  117.00  131.0  147.50  173.0
# 시프      13.0  116.230769  13.510205  92.0  115.00  120.0  123.00  139.0
# 썬콜     343.0  123.711370  18.665290  80.0  109.00  124.0  138.00  168.0
# 용기사    314.0  129.958599  21.045551  83.0  115.00  129.5  147.00  200.0
# 저격수     82.0  119.402439  20.308035  83.0  101.25  120.5  135.00  159.0
# 크루세이더  227.0  128.801762  23.129692  82.0  111.50  128.0  146.00  200.0
# 프리스트   700.0  113.432857  18.328814  80.0   99.00  111.0  127.00  178.0
# 허밋     539.0  125.936920  20.861726  81.0  112.00  125.0  142.00  173.0

# %%
# 1. Map Distribution
def map_dist(df):
    plt.figure(figsize=(10, 6))
    sns.countplot(y="map", data=df, order=map_counts.index, palette="viridis")
    plt.title("Frequency of Maps")
    plt.xlabel("Count")
    plt.ylabel("Map")
    plt.tight_layout()
    plt.show()

# 2. Job Distribution
def job_dist(df):
    plt.figure(figsize=(10, 6))
    sns.countplot(y="job", data=df, order=job_counts.index, palette="coolwarm")
    plt.title("Frequency of Jobs")
    plt.xlabel("Count")
    plt.ylabel("Job")
    plt.tight_layout()
    plt.show()

# 3. Level Distribution Overall
def level_dist(df):
    plt.figure(figsize=(10, 6))
    sns.histplot(df["level"], kde=True, bins=30, color="skyblue")
    plt.title("Level Distribution")
    plt.xlabel("Level")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# 4. Level Distribution by Job
def level_dist_by_job(df):
    plt.figure(figsize=(12, 8))
    sns.boxplot(x=df["job"], y=df["level"], data=df, palette="muted")
    plt.title("Level Distribution by Job")
    plt.xlabel("Job")
    plt.ylabel("Level")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
map_dist(df)
job_dist(df)
level_dist(df)
level_dist_by_job(df)
average_spec_by_job(processed_df)
plot_job_frequency_by_map(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       3 level_dist(df)
#       4 level_dist_by_job(df)
# ----> 5 average_spec_by_job(processed_df)
#       6 plot_job_frequency_by_map(df)
#
# NameError: name 'average_spec_by_job' is not defined
