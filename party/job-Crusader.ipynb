# %%
# %run data_loading.ipynb
# Out:
# Data saved as data/output/1219.csv
# Processed valid data saved as data/output/1219_processed.csv
# Data saved as data/output/1218.csv
# Processed valid data saved as data/output/1218_processed.csv
# Data saved as data/output/1220.csv
# Processed valid data saved as data/output/1220_processed.csv
# Data saved as data/output/1221.csv
# Processed valid data saved as data/output/1221_processed.csv
# Data saved as data/output/1213.csv
# Processed valid data saved as data/output/1213_processed.csv
# Data saved as data/output/1212.csv
# Processed valid data saved as data/output/1212_processed.csv
# Data saved as data/output/1211.csv
# Processed valid data saved as data/output/1211_processed.csv
# Data saved as data/output/1215.csv
# Processed valid data saved as data/output/1215_processed.csv
# Data saved as data/output/1214.csv
# Processed valid data saved as data/output/1214_processed.csv
# Data saved as data/output/1216.csv
# Processed valid data saved as data/output/1216_processed.csv
# Data saved as data/output/1217.csv
# Processed valid data saved as data/output/1217_processed.csv
# Upper level threshold (top 99.99%): 176.9526999999989
# Lower level threshold (bottom 0.010000000000005116%): 80.0
# Level Outliers:
#      party_id      time level   job  spec  map        date valid  valid_spec  \
# 350       198   오후 9:10    80    허밋  None  망용둥  2024-12-19  True       False
# 1317      228   오후 4:38    80  프리스트  None  망둥쩔  2024-12-12  True       False
# 1473      100   오후 1:16    80   나이트  None   하둥  2024-12-11  True       False
# 1606      285   오후 1:37   178  프리스트  1100   큰둥  2024-12-11  True        True
# 2519      188  오전 12:46    80    썬콜  None   하둥  2024-12-16  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 350       18.446821          18.446821  1515.770758            NaN
# 1317            NaN                NaN          NaN            NaN
# 1473      30.412222          30.412222  2389.041294            NaN
# 1606       6.179775           6.206757  1100.000000    1093.793243
# 2519       6.226383           6.226383   489.936503            NaN
#
#       avg_distance_per_job
# 350            2415.678179
# 1317                   NaN
# 1473           4429.587778
# 1606            886.793243
# 2519            804.696694
# Upper level threshold (top 99.999%): 177.96807999999965
# Lower level threshold (bottom 0.0010000000000047748%): 82.0
# Level Outliers:
#     party_id     time level    job  spec map        date valid  valid_spec  \
# 67       131  오후 2:13    82     허밋  1750  붉켄  2024-12-18  True        True
# 168      285  오후 1:37   178   프리스트  1100  큰둥  2024-12-11  True        True
# 324      537  오전 1:32    82  크루세이더  2800  듀파  2024-12-16  True        True
#
#      spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 67       21.341463          18.275360       1750.0    1731.724640
# 168       6.179775           6.206757       1100.0    1093.793243
# 324      34.146341          32.285642       2800.0    2767.714358
#
#      avg_distance_per_job
# 67            2139.224640
# 168            886.793243
# 324           3817.596711
# Combined raw data saved as 'data/output/df.csv'
# Combined processed data saved as 'data/output/processed_df.csv'

# %%
df_cr[(df_cr['spec_filled'] < 2400)]
# Out:
#      party_id      time  level    job  spec   map        date  valid  \
# 624         8  오전 12:36  111.0  크루세이더  None   블와둥  2024-12-20   True
# 640        15  오전 12:36   97.0  크루세이더  None    듀파  2024-12-20   True
# 652        23  오전 12:37  113.0  크루세이더  None   블와둥  2024-12-20   True
# 674        34  오전 12:37   92.0  크루세이더  None    듀파  2024-12-20   True
# 681        39  오전 12:38  147.0  크루세이더  None   블와둥  2024-12-20   True
# 705        55  오전 12:50   87.0  크루세이더  None    듀파  2024-12-20   True
# 772        89  오전 12:52  126.0  크루세이더  None    듀파  2024-12-20   True
# 794         8   오후 1:51  168.0  크루세이더  None   깊바협  2024-12-21   True
# 796         8   오후 1:51  153.0  크루세이더  None   깊바협  2024-12-21   True
# 837        28   오후 1:52  134.0  크루세이더  None  None  2024-12-21  False
# 905       120   오후 1:53   94.0  크루세이더  None    듀파  2024-12-21   True
# 914       124   오후 1:53  144.0  크루세이더  None   깊바협  2024-12-21   True
# 922       126   오후 1:53  126.0  크루세이더  None  None  2024-12-21  False
# 937       136   오후 1:54  109.0  크루세이더  None   블와둥  2024-12-21   True
# 940       140   오후 1:54  124.0  크루세이더  None   깊바협  2024-12-21   True
# 942       140   오후 1:54  149.0  크루세이더  None   깊바협  2024-12-21   True
# 952       144   오후 1:54  168.0  크루세이더  None   블와둥  2024-12-21   True
# 970       157   오후 2:20  123.0  크루세이더  None   오징어  2024-12-21   True
# 976       159   오후 2:20  131.0  크루세이더  None   깊바협  2024-12-21   True
# 1020      193   오후 2:21  162.0  크루세이더  None   깊바협  2024-12-21   True
# 1021      194   오후 2:21  125.0  크루세이더  None   깊바협  2024-12-21   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  \
# 624        False            NaN                NaN  2196.617403
# 640        False            NaN                NaN  2196.617403
# 652        False            NaN                NaN  2196.617403
# 674        False            NaN                NaN  2196.617403
# 681        False            NaN                NaN  2196.617403
# 705        False            NaN                NaN  2196.617403
# 772        False            NaN                NaN  2196.617403
# 794        False            NaN                NaN  2196.617403
# 796        False            NaN                NaN  2196.617403
# 837        False            NaN                NaN  2196.617403
# 905        False            NaN                NaN  2196.617403
# 914        False            NaN                NaN  2196.617403
# 922        False            NaN                NaN  2196.617403
# 937        False            NaN                NaN  2196.617403
# 940        False            NaN                NaN  2196.617403
# 942        False            NaN                NaN  2196.617403
# 952        False            NaN                NaN  2196.617403
# 970        False            NaN                NaN  2196.617403
# 976        False            NaN                NaN  2196.617403
# 1020       False            NaN                NaN  2196.617403
# 1021       False            NaN                NaN  2196.617403
#
#       spec_distance  avg_distance_per_job  tsne_dim1  tsne_dim2  \
# 624             NaN                   NaN   7.367417  11.188795
# 640             NaN                   NaN  13.585156  13.595744
# 652             NaN                   NaN   7.329754  11.185514
# 674             NaN                   NaN  13.933084  13.720721
# 681             NaN                   NaN   4.004903  10.140225
# 705             NaN                   NaN  14.305628  13.951655
# 772             NaN                   NaN   5.917086  11.697556
# 794             NaN                   NaN   3.182899  10.831887
# 796             NaN                   NaN   3.551189  11.040767
# 837             NaN                   NaN   5.429836  10.544924
# 905             NaN                   NaN  13.781829  13.653772
# 914             NaN                   NaN   3.927588  11.206177
# 922             NaN                   NaN   5.551758  10.576226
# 937             NaN                   NaN   7.401077  11.190355
# 940             NaN                   NaN   4.693995  11.531264
# 942             NaN                   NaN   3.704048  11.113686
# 952             NaN                   NaN   3.568469  10.093170
# 970             NaN                   NaN   5.846200  11.294806
# 976             NaN                   NaN   4.486137  11.428948
# 1020            NaN                   NaN   3.299950  10.903996
# 1021            NaN                   NaN   4.671511  11.517303
#
#       distance_to_nearest
# 624              0.033697
# 640              0.205054
# 652              0.037805
# 674              0.165409
# 681              0.438964
# 705              0.438315
# 772              0.408941
# 794              0.137479
# 796              0.169361
# 837              0.125876
# 905              0.165409
# 914              0.241919
# 922              0.125876
# 937              0.033697
# 940              0.026466
# 942              0.169361
# 952              0.438964
# 970              0.408941
# 976              0.205354
# 1020             0.137479
# 1021             0.026466

# %%
df_cr = df[(df['job'] == '크루세이더')]
df_cr
# Out:
#      party_id      time level    job  spec   map        date  valid  \
# 10          4  오전 12:33   145  크루세이더  None   깊바협  2024-12-19   True
# 11          4  오전 12:33   158  크루세이더  None   깊바협  2024-12-19   True
# 15          7  오전 12:33   134  크루세이더  None  None  2024-12-19  False
# 58         33  오전 12:34   118  크루세이더  None    협동  2024-12-19   True
# 81         45  오전 12:35   126  크루세이더  4000  None  2024-12-19  False
# ...       ...       ...   ...    ...   ...   ...         ...    ...
# 3440      235   오후 1:56   117  크루세이더  None  None  2024-12-17  False
# 3447      242   오후 1:56   144  크루세이더  4800   블와둥  2024-12-17   True
# 3452      247   오후 1:57    97  크루세이더  3290    듀파  2024-12-17   True
# 3453      247   오후 1:57    97  크루세이더  None    듀파  2024-12-17   True
# 3480      290   오후 1:59   106  크루세이더  None   불어전  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  \
# 10         False      32.403057          32.403057  4791.476083
# 11         False      32.403057          32.403057  5197.198616
# 15         False      32.403057          32.403057  4234.231742
# 58         False      32.403057          32.403057  3893.120688
# 81          True      31.746032          32.403057  4000.000000
# ...          ...            ...                ...          ...
# 3440       False      32.663128          32.663128  3903.676890
# 3447        True      33.333333          32.663128  4800.000000
# 3452        True      33.917526          32.663128  3290.000000
# 3453       False      32.663128          32.663128  3158.678993
# 3480       False      32.663128          32.663128  3445.866875
#
#       spec_distance  avg_distance_per_job
# 10              NaN           4185.596943
# 11              NaN           4185.596943
# 15              NaN           4185.596943
# 58              NaN           4185.596943
# 81      3967.596943           4185.596943
# ...             ...                   ...
# 3440            NaN           4151.765444
# 3447    4767.336872           4151.765444
# 3452    3257.336872           4151.765444
# 3453            NaN           4151.765444
# 3480            NaN           4151.765444
#
# [288 rows x 14 columns]

# %%
processed_df_cr = processed_df[(processed_df['job'] == '크루세이더')]
print(len(processed_df_cr))
processed_df_cr.head()
# Out:
# 47
#    party_id      time level    job  spec  map        date valid  valid_spec  \
# 9        55  오전 12:36    95  크루세이더  3100   듀파  2024-12-19  True        True
# 16       70  오전 12:37   157  크루세이더  5040  블와둥  2024-12-19  True        True
# 27      125   오후 9:07   143  크루세이더  4772  깊바협  2024-12-19  True        True
# 29      138   오후 9:08    88  크루세이더  2900   듀파  2024-12-19  True        True
# 34      170   오후 9:09   119  크루세이더  3800   협동  2024-12-19  True        True
#
#     spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 9       32.631579          32.403057       3100.0    3067.596943
# 16      32.101911          32.403057       5040.0    5007.596943
# 27      33.370629          32.403057       4772.0    4739.596943
# 29      32.954545          32.403057       2900.0    2867.596943
# 34      31.932773          32.403057       3800.0    3767.596943
#
#     avg_distance_per_job
# 9            4185.596943
# 16           4185.596943
# 27           4185.596943
# 29           4185.596943
# 34           4185.596943

# %%
# %run eda.ipynb

map_dist(df)
map_dist(df_cr)
job_dist(df)
level_dist(df)
level_dist(df_cr)
level_dist_by_job(df)
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   party_id              3487 non-null   int64
#  1   time                  3487 non-null   object
#  2   level                 3487 non-null   int64
#  3   job                   3487 non-null   object
#  4   spec                  462 non-null    float64
#  5   map                   3128 non-null   object
#  6   date                  3487 non-null   object
#  7   valid                 3487 non-null   bool
#  8   valid_spec            3487 non-null   bool
#  9   spec_by_level         3188 non-null   float64
#  10  avg_spec_by_level     3188 non-null   float64
#  11  spec_filled           3188 non-null   float64
#  12  spec_distance         462 non-null    float64
#  13  avg_distance_per_job  3188 non-null   float64
# dtypes: bool(2), float64(6), int64(2), object(4)
# memory usage: 333.8+ KB
# None
#
# Data Overview:
#    party_id      time  level  job   spec map        date  valid  valid_spec  \
# 0         1  오전 12:33     88   허밋    NaN  붉켄  2024-12-19   True       False
# 1         1  오전 12:33    101  레인저    NaN  붉켄  2024-12-19   True       False
# 2         2  오전 12:33     90   허밋    NaN  붉켄  2024-12-19   True       False
# 3         2  오전 12:33     99   허밋    NaN  붉켄  2024-12-19   True       False
# 4         2  오전 12:33    105   썬콜  650.0  붉켄  2024-12-19   True        True
#
#    spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 0      18.446821          18.446821  1668.361778            NaN
# 1      22.312474          22.312474  2291.304574            NaN
# 2      18.446821          18.446821  1683.630480            NaN
# 3      18.446821          18.446821  1858.638611            NaN
# 4       6.190476           6.212019   650.000000     643.787981
#
#    avg_distance_per_job
# 0           2415.678179
# 1           2402.687526
# 2           2415.678179
# 3           2415.678179
# 4            793.121314
#
# Map Frequency:
# map
# 협동     426
# 불어전    386
# 망용둥    377
# 듀파     325
# 블와둥    297
# 붉켄     226
# 깊바협    183
# 검켄     166
# 레와둥    147
# 산양     114
# 하둥      99
# 오징어     87
# 갈림길     69
# 와협      56
# 망둥쩔     45
# 푸켄      37
# 물어전     33
# 위둥      24
# 큰둥      16
# 남둥      15
# Name: count, dtype: int64
#
# Job Frequency:
# job
# 프리스트     900
# 허밋       712
# 썬콜       463
# 용기사      426
# 레인저      334
# 크루세이더    288
# 불독       128
# 저격수      118
# 나이트       99
# 시프        19
# Name: count, dtype: int64
#
# Level Statistics by Job:
#        count        mean        std   min    25%    50%     75%    max
# job
# 나이트     99.0  117.676768  18.713647  82.0  106.5  120.0  130.00  157.0
# 레인저    334.0  122.940120  18.300035  84.0  109.0  122.0  134.00  173.0
# 불독     128.0  132.554688  19.287632  87.0  117.0  131.0  149.25  173.0
# 시프      19.0  116.000000  13.630032  92.0  112.0  118.0  123.00  140.0
# 썬콜     463.0  124.194384  18.150078  84.0  110.0  125.0  138.00  169.0
# 용기사    426.0  129.481221  20.710915  81.0  115.0  129.0  146.00  175.0
# 저격수    118.0  118.033898  19.528604  83.0  102.0  118.0  133.00  160.0
# 크루세이더  288.0  127.954861  22.580588  82.0  111.0  127.0  145.00  175.0
# 프리스트   900.0  113.965556  18.257031  81.0   99.0  112.0  128.00  168.0
# 허밋     712.0  125.455056  21.442251  81.0  110.0  124.0  142.00  173.0

# %%
# %run data_visualization.ipynb

job="크루세이더"
jobs=["크루세이더", "용기사"]
input_map="블와둥"
input_maps=["블와둥", "협동", "깊바협"]
start_level=120
end_level=160
input_level=145

#1 직업별 평균 스펙
# average_spec_by_job(df)
#2 맵별 직업 분포
# plot_job_frequency_by_map(df)
#3 특정 직업, 레벨(optional), 스펙_filled
plot_level_spec_with_regression(df, job)
plot_level_spec_with_regression(df, job, input_level=131, use_spec_filled=True)
#4 레벨+-5의 스펙 회귀
# plot_level_spec_with_regression_by_level(df, job, input_level)
#5 특정 직업의 레벨 별 맵 분포
plot_level_by_map_by_job(df, job)
#6 특정직업의 레벨별 사냥터 분포(5%+)
plot_level_distribution_by_job_and_map(df, job)
#7 특정 직업의 레벨별 맵 히트맵
plot_map_level_heatmap_for_job(df, job)
#8 특정직업의 레벨 범위별 사냥터 히트맵 
plot_map_frequency_by_level_range(df, job)
#9 맵별 스펙 기재 여부
visualize_spec_validity_by_map(df, job='all')
#10 직업별 스펙 기재 여부, job optional
visualize_spec_validity_by_jobs(df)
#11 날짜별 맵 사용 비율
# visualize_map_distribution_by_date(df)
visualize_map_distribution_by_date(df_cr)
#12 직업별 레벨(범위 설정 가능)당 스펙
# visualize_level_spec_comparison(df, jobs=None, start_level=None, end_level=None)
#13 직업별 레벨에 따른 스공과 맵, 회귀
# plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#14 맵 사용빈도 변화 추이
visualize_map_percentage_change(df_cr, map)
visualize_map_percentage_change(df_cr, "깊바협")
# visualize_map_percentage_change(df_il, input_map)
#15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
plot_level_spec_distribution_of_job_and_map(df, input_map, job, use_spec_filled=True)
#16 특정 직업의 맵별분포와 레벨, 스펙 회귀
plot_level_spec_distribution_of_job(df, job, use_spec_filled=False)
# Out:
# Map '<class 'map'>' not found in the data.

# %%
# %run modeling.ipynb

recommend_map_knn(100, job, level_range=5)
recommend_map_svd(100, job, level_range=5)

recommend_map_knn(120, job, level_range=5)
recommend_map_svd(120, job, level_range=5)

recommend_map_knn(140, job, level_range=5)
recommend_map_svd(140, job, level_range=5)

# tsne_visualization(df)
df_with_tsne = apply_tsne(df)  # Apply t-SNE
df_filtered, outliers = filter_outliers_by_tsne(df_with_tsne, top_percentile=99.9)
visualize_tsne(df_filtered)

# tsne_visualization(df)
df_with_tsne = apply_tsne(df_cr)  # Apply t-SNE
df_filtered, outliers = filter_outliers_by_tsne(df_with_tsne, top_percentile=99.9)
visualize_tsne(df_filtered)
# Out:
# Similarity scores for recommended maps:
# Map: 듀파, Score: 18.52969315823566
# Recommended Maps and Scores: ['듀파']
# Unique maps after preprocessing:
# ['깊바협' '협동' '듀파' '오징어' '블와둥']
# Similarity scores for recommended maps:
# Map: 듀파, Score: 0.4999999999999999
# Map: 깊바협, Score: 0.4999999999999995
# Map: 블와둥, Score: -5.204170427930421e-18
# Recommended Maps: Index(['듀파', '깊바협', '블와둥'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 협동, Score: 5.807916641075589
# Map: 듀파, Score: 6.415295451889129
# Recommended Maps and Scores: ['협동', '듀파']
# Unique maps after preprocessing:
# ['깊바협' '협동' '듀파' '오징어' '블와둥']
# Similarity scores for recommended maps:
# Map: 듀파, Score: 0.3333333333333334
# Map: 블와둥, Score: 0.3333333333333333
# Map: 깊바협, Score: 0.3333333333333328
# Recommended Maps: Index(['듀파', '블와둥', '깊바협'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 6.490912137426676
# Map: 산양, Score: 10.577241564773031
# Recommended Maps and Scores: ['깊바협', '산양']
# Unique maps after preprocessing:
# ['깊바협' '협동' '듀파' '오징어' '블와둥']
# Similarity scores for recommended maps:
# Map: 블와둥, Score: 0.4999999999999997
# Map: 깊바협, Score: 0.49999999999999944
# Map: 듀파, Score: 4.683753385137379e-17
# Recommended Maps: Index(['블와둥', '깊바협', '듀파'], dtype='object', name='map')
# Filtering out the top 99.9% outliers with distance greater than 3.0790103385169267
#       party_id      time  level  job  spec map        date  valid  valid_spec  \
# 688         43  오전 12:38   93.0   시프   NaN  듀파  2024-12-20   True       False
# 1831        32   오후 3:48  139.0   시프   NaN  듀파  2024-12-15   True       False
# 2341        25  오전 12:19  115.0  용기사   NaN  검켄  2024-12-16   True       False
# 3394       194   오후 1:53   92.0   시프   NaN  붉켄  2024-12-17   True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 688             NaN                NaN  2198.495462            NaN
# 1831            NaN                NaN  2198.495462            NaN
# 2341      35.369864          35.369864  4167.212174            NaN
# 3394            NaN                NaN  2198.495462            NaN
#
#       avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 688                    NaN  -0.562550 -16.148268             5.224785
# 1831                   NaN  -2.746958 -36.401360             5.383083
# 2341           4700.830136  33.351151 -40.158733             3.564879
# 3394                   NaN -12.136600 -23.503063             3.095310
# Filtering out the top 99.9% outliers with distance greater than 1.5392823960583735
#      party_id     time  level    job  spec map        date valid  valid_spec  \
# 1980      124  오후 5:45  143.0  크루세이더  None  검켄  2024-12-15  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 1980      32.606408          32.606408  4771.239252            NaN
#
#       avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 1980           3489.993592  -7.160516  -4.312886             1.560694
