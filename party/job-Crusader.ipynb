# %%
# %run data_loading.ipynb
# Out:
# Data saved as data/output/1219.csv
# Processed valid data saved as data/output/1219_processed.csv
# Data saved as data/output/1218.csv
# Processed valid data saved as data/output/1218_processed.csv
# Data saved as data/output/1220.csv
# Processed valid data saved as data/output/1220_processed.csv
# Data saved as data/output/1221.csv
# Processed valid data saved as data/output/1221_processed.csv
# Data saved as data/output/1213.csv
# Processed valid data saved as data/output/1213_processed.csv
# Data saved as data/output/1212.csv
# Processed valid data saved as data/output/1212_processed.csv
# Data saved as data/output/1211.csv
# Processed valid data saved as data/output/1211_processed.csv
# Data saved as data/output/1215.csv
# Processed valid data saved as data/output/1215_processed.csv
# Data saved as data/output/1214.csv
# Processed valid data saved as data/output/1214_processed.csv
# Data saved as data/output/1216.csv
# Processed valid data saved as data/output/1216_processed.csv
# Data saved as data/output/1217.csv
# Processed valid data saved as data/output/1217_processed.csv
# Combined raw data saved as 'data/output/df.csv'
# Combined valid processed data saved as 'data/output/processed_df.csv'

# %%
df
# Out:
#      party_id      time level   job  spec   map        date  valid  \
# 0           1  오전 12:33    88    허밋  None    붉켄  2024-12-19   True
# 1           1  오전 12:33   101   레인저  None    붉켄  2024-12-19   True
# 2           2  오전 12:33    90    허밋  None    붉켄  2024-12-19   True
# 3           2  오전 12:33    99    허밋  None    붉켄  2024-12-19   True
# 4           2  오전 12:33   105    썬콜   650    붉켄  2024-12-19   True
# ...       ...       ...   ...   ...   ...   ...         ...    ...
# 3478      292   오후 1:59   143   용기사  5000   블와둥  2024-12-17   True
# 3479      297   오후 1:59   119  프리스트  None    검켄  2024-12-17   True
# 3480      297   오후 1:59   134  프리스트  None    검켄  2024-12-17   True
# 3481      300   오후 1:59   123  프리스트  None  None  2024-12-17  False
# 3482      301   오후 1:59   112    허밋  None    검켄  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  \
# 0          False      18.446821          18.446821  1617.806510
# 1          False      22.312474          22.312474  2315.656009
# 2          False      18.446821          18.446821  1686.287244
# 3          False      18.446821          18.446821  1814.608369
# 4           True       6.190476           6.212019   650.000000
# ...          ...            ...                ...          ...
# 3478        True      34.965035          35.282984  5000.000000
# 3479       False       6.320755           6.320755   761.303990
# 3480       False       6.320755           6.320755   855.827203
# 3481       False       6.320755           6.320755   791.059693
# 3482       False      18.956725          18.956725  2149.230990
#
#       spec_distance  avg_distance_per_job
# 0               NaN           2415.678179
# 1               NaN           2402.687526
# 2               NaN           2415.678179
# 3               NaN           2415.678179
# 4        643.787981            793.121314
# ...             ...                   ...
# 3478    4964.717016           4940.217016
# 3479            NaN            663.679245
# 3480            NaN            663.679245
# 3481            NaN            663.679245
# 3482            NaN           2502.176609
#
# [3483 rows x 14 columns]

# %%
df_dk = df[(df['job'] == '크루세이더')]
df_dk
# Out:
#      party_id      time level    job  spec   map        date  valid  \
# 10          4  오전 12:33   145  크루세이더  None   깊바협  2024-12-19   True
# 11          4  오전 12:33   158  크루세이더  None   깊바협  2024-12-19   True
# 15          7  오전 12:33   134  크루세이더  None  None  2024-12-19  False
# 59         33  오전 12:34   118  크루세이더  None    협동  2024-12-19   True
# 82         45  오전 12:35   126  크루세이더  4000  None  2024-12-19  False
# ...       ...       ...   ...    ...   ...   ...         ...    ...
# 3489      235   오후 1:56   117  크루세이더  None  None  2024-12-17  False
# 3496      242   오후 1:56   144  크루세이더  4800   블와둥  2024-12-17   True
# 3501      247   오후 1:57    97  크루세이더  3290    듀파  2024-12-17   True
# 3502      247   오후 1:57    97  크루세이더  None    듀파  2024-12-17   True
# 3529      290   오후 1:59   106  크루세이더  None   불어전  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  \
# 10         False      32.403057          32.403057  4653.683576
# 11         False      32.403057          32.403057  4990.434789
# 15         False      32.403057          32.403057  4377.259312
# 59         False      32.403057          32.403057  3711.173794
# 82          True      31.746032          32.403057  4000.000000
# ...          ...            ...                ...          ...
# 3489       False      32.663128          32.663128  3929.199321
# 3496        True      33.333333          32.663128  4800.000000
# 3501        True      33.917526          32.663128  3290.000000
# 3502       False      32.663128          32.663128  3188.532294
# 3529       False      32.663128          32.663128  3433.932397
#
#       spec_distance  avg_distance_per_job
# 10              NaN           4185.596943
# 11              NaN           4185.596943
# 15              NaN           4185.596943
# 59              NaN           4185.596943
# 82      3967.596943           4185.596943
# ...             ...                   ...
# 3489            NaN           4151.765444
# 3496    4767.336872           4151.765444
# 3501    3257.336872           4151.765444
# 3502            NaN           4151.765444
# 3529            NaN           4151.765444
#
# [291 rows x 14 columns]

# %%
processed_df_cr = processed_df[(processed_df['job'] == '크루세이더')]
print(len(processed_df_cr))
processed_df_cr.head()
# Out:
# 48
#    party_id      time level    job  spec  map        date valid  valid_spec  \
# 9        55  오전 12:36    95  크루세이더  3100   듀파  2024-12-19  True        True
# 16       70  오전 12:37   157  크루세이더  5040  블와둥  2024-12-19  True        True
# 27      125   오후 9:07   143  크루세이더  4772  깊바협  2024-12-19  True        True
# 29      138   오후 9:08    88  크루세이더  2900   듀파  2024-12-19  True        True
# 34      170   오후 9:09   119  크루세이더  3800   협동  2024-12-19  True        True
#
#     spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 9       32.631579          32.403057       3100.0    3067.596943
# 16      32.101911          32.403057       5040.0    5007.596943
# 27      33.370629          32.403057       4772.0    4739.596943
# 29      32.954545          32.403057       2900.0    2867.596943
# 34      31.932773          32.403057       3800.0    3767.596943
#
#     avg_distance_per_job
# 9            4185.596943
# 16           4185.596943
# 27           4185.596943
# 29           4185.596943
# 34           4185.596943

# %%
# %run eda.ipynb

map_dist(df)
map_dist(df_cr)
job_dist(df)
level_dist(df)
level_dist(df_cr)
level_dist_by_job(df)
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3541 entries, 0 to 3540
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   party_id              3541 non-null   int64
#  1   time                  3541 non-null   object
#  2   level                 3494 non-null   float64
#  3   job                   3541 non-null   object
#  4   spec                  464 non-null    float64
#  5   map                   3169 non-null   object
#  6   date                  3541 non-null   object
#  7   valid                 3541 non-null   bool
#  8   valid_spec            3541 non-null   bool
#  9   spec_by_level         3238 non-null   float64
#  10  avg_spec_by_level     3238 non-null   float64
#  11  spec_filled           3195 non-null   float64
#  12  spec_distance         464 non-null    float64
#  13  avg_distance_per_job  3238 non-null   float64
# dtypes: bool(2), float64(7), int64(1), object(4)
# memory usage: 339.0+ KB
# None
#
# Data Overview:
#    party_id      time  level  job   spec map        date  valid  valid_spec  \
# 0         1  오전 12:33   88.0   허밋    NaN  붉켄  2024-12-19   True       False
# 1         1  오전 12:33  101.0  레인저    NaN  붉켄  2024-12-19   True       False
# 2         2  오전 12:33   90.0   허밋    NaN  붉켄  2024-12-19   True       False
# 3         2  오전 12:33   99.0   허밋    NaN  붉켄  2024-12-19   True       False
# 4         2  오전 12:33  105.0   썬콜  650.0  붉켄  2024-12-19   True        True
#
#    spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 0      18.446821          18.446821  1635.643787            NaN
# 1      22.312474          22.312474  2213.443769            NaN
# 2      18.446821          18.446821  1686.610461            NaN
# 3      18.446821          18.446821  1851.835536            NaN
# 4       6.190476           6.212019   650.000000     643.787981
#
#    avg_distance_per_job
# 0           2415.678179
# 1           2402.687526
# 2           2415.678179
# 3           2415.678179
# 4            793.121314
#
# Map Frequency:
# map
# 협동     429
# 불어전    394
# 망용둥    384
# 듀파     325
# 블와둥    297
# 붉켄     227
# 깊바협    185
# 검켄     166
# 레와둥    155
# 산양     115
# 하둥     101
# 오징어     87
# 갈림길     69
# 와협      57
# 망둥쩔     52
# 푸켄      37
# 물어전     33
# 위둥      24
# 큰둥      17
# 남둥      15
# Name: count, dtype: int64
#
# Job Frequency:
# job
# 프리스트     908
# 허밋       721
# 썬콜       472
# 용기사      433
# 레인저      349
# 크루세이더    291
# 불독       130
# 저격수      118
# 나이트      100
# 시프        19
# Name: count, dtype: int64
#
# Level Statistics by Job:
#        count        mean        std   min    25%    50%     75%    max
# job
# 나이트    100.0  117.300000  18.996278  80.0  106.0  119.0  130.00  157.0
# 레인저    334.0  122.940120  18.300035  84.0  109.0  122.0  134.00  173.0
# 불독     128.0  132.554688  19.287632  87.0  117.0  131.0  149.25  173.0
# 시프      19.0  116.000000  13.630032  92.0  112.0  118.0  123.00  140.0
# 썬콜     464.0  124.099138  18.246183  80.0  110.0  125.0  138.00  169.0
# 용기사    427.0  129.646370  20.966192  81.0  115.0  129.0  146.00  200.0
# 저격수    118.0  118.033898  19.528604  83.0  102.0  118.0  133.00  160.0
# 크루세이더  289.0  128.204152  22.936276  82.0  111.0  127.0  145.00  200.0
# 프리스트   902.0  113.998891  18.395911  80.0   99.0  112.0  128.00  178.0
# 허밋     713.0  125.391304  21.494702  80.0  110.0  124.0  142.00  173.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 get_ipython().run_line_magic('run', 'eda.ipynb')
#       3 map_dist(df)
# ----> 4 map_dist(df_cr)
#       5 job_dist(df)
#       6 level_dist(df)
#
# NameError: name 'df_cr' is not defined

# %%
# %run data_visualization.ipynb

job="크루세이더"
jobs=["용기사", "크루세이더"]
input_map="블와둥"
input_maps=["블와둥", "협동", "깊바협"]
start_level=120
end_level=160
input_level=145

#1 직업별 평균 스펙
# average_spec_by_job(df)
#2 맵별 직업 분포
# plot_job_frequency_by_map(df)
#3 특정 직업, 레벨(optional), 스펙_filled
plot_level_spec_with_regression(df, job)
plot_level_spec_with_regression(df, job, input_level=input_level, use_spec_filled=True)
#4 레벨+-5의 스펙 회귀
# plot_level_spec_with_regression_by_level(df, job, input_level)
#5 특정 직업의 레벨 별 맵 분포
plot_level_by_map_by_job(df, job)
#6 특정직업의 레벨별 사냥터 분포(5%+)
plot_level_distribution_by_job_and_map(df, job)
#7 특정 직업의 레벨별 맵 히트맵
plot_map_level_heatmap_for_job(df, job)
#8 특정직업의 레벨 범위별 사냥터 히트맵 
plot_map_frequency_by_level_range(df, job)
#9 맵별 스펙 기재 여부
visualize_spec_validity_by_map(df, job='all')
visualize_spec_validity_by_map(df, job=job)
#10 직업별 스펙 기재 여부, job optional
visualize_spec_validity_by_jobs(df, jobs=None)
#11 날짜별 맵 사용 비율
# visualize_map_distribution_by_date(df)
# visualize_map_distribution_by_date(df_il)
#12 직업별 레벨(범위 설정 가능)당 스펙
# visualize_level_spec_comparison(df, jobs=None, start_level=None, end_level=None)
#13 직업별 레벨에 따른 스공과 맵, 회귀
# plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#14 맵 사용빈도 변화 추이
visualize_map_percentage_change(df_il, "불어전")
# visualize_map_percentage_change(df_il, input_map)
#15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
# plot_level_spec_distribution_of_job_and_map(df, "불어전", job, use_spec_filled=False)
plot_level_spec_distribution_of_job_and_map(df, input_map, job, use_spec_filled=False)
#16 특정 직업의 맵별분포와 레벨, 스펙 회귀
plot_level_spec_distribution_of_job(df, job)
plot_level_spec_distribution_of_job(df, "허밋")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 41
#      32 visualize_spec_validity_by_jobs(df, jobs=None)
#      33 #11 날짜별 맵 사용 비율
#      34 # visualize_map_distribution_by_date(df)
#      35 # visualize_map_distribution_by_date(df_il)
#    (...)
#      39 # plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#      40 #14 맵 사용빈도 변화 추이
# ---> 41 visualize_map_percentage_change(df_il, "불어전")
#      42 # visualize_map_percentage_change(df_il, input_map)
#      43 #15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
#      44 # plot_level_spec_distribution_of_job_and_map(df, "불어전", job, use_spec_filled=False)
#      45 plot_level_spec_distribution_of_job_and_map(df, input_map, job, use_spec_filled=False)
#
# NameError: name 'df_il' is not defined

# %%
# %run modeling.ipynb

recommend_map_knn(100, job, level_range=5)
recommend_map_svd(100, job, level_range=5)

recommend_map_knn(120, job, level_range=5)
recommend_map_svd(120, job, level_range=5)

recommend_map_knn(140, job, level_range=5)
recommend_map_svd(140, job, level_range=5)

tsne_visualization(df)
tsne_visualization(df, jobs=[job])
