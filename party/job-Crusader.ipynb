# %%
# %run data_loading.ipynb
# Out:
# Data saved as data/output/1219.csv
# Processed valid data saved as data/output/1219_processed.csv
# Data saved as data/output/1218.csv
# Processed valid data saved as data/output/1218_processed.csv
# Data saved as data/output/1220.csv
# Processed valid data saved as data/output/1220_processed.csv
# Data saved as data/output/1221.csv
# Processed valid data saved as data/output/1221_processed.csv
# Data saved as data/output/1213.csv
# Processed valid data saved as data/output/1213_processed.csv
# Data saved as data/output/1212.csv
# Processed valid data saved as data/output/1212_processed.csv
# Data saved as data/output/1211.csv
# Processed valid data saved as data/output/1211_processed.csv
# Data saved as data/output/1215.csv
# Processed valid data saved as data/output/1215_processed.csv
# Data saved as data/output/1214.csv
# Processed valid data saved as data/output/1214_processed.csv
# Data saved as data/output/1216.csv
# Processed valid data saved as data/output/1216_processed.csv
# Data saved as data/output/1217.csv
# Processed valid data saved as data/output/1217_processed.csv
# Upper level threshold (top 99.99%): 176.9526999999989
# Lower level threshold (bottom 0.010000000000005116%): 80.0
# Level Outliers:
#      party_id      time level   job  spec  map        date valid  valid_spec  \
# 354       198   오후 9:10    80    허밋  None  망용둥  2024-12-19  True       False
# 1339      228   오후 4:38    80  프리스트  None  망둥쩔  2024-12-12  True       False
# 1498      100   오후 1:16    80   나이트  None   하둥  2024-12-11  True       False
# 1635      285   오후 1:37   178  프리스트  1100   큰둥  2024-12-11  True        True
# 2558      188  오전 12:46    80    썬콜  None   하둥  2024-12-16  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 354       18.446821          18.446821  1509.809526            NaN
# 1339            NaN                NaN          NaN            NaN
# 1498      30.412222          30.412222  2450.427848            NaN
# 1635       6.179775           6.206757  1100.000000    1093.793243
# 2558       6.226383           6.226383   506.276175            NaN
#
#       avg_distance_per_job
# 354            2415.678179
# 1339                   NaN
# 1498           4429.587778
# 1635            886.793243
# 2558            804.696694
# Upper level threshold (top 99.999%): 177.96807999999965
# Lower level threshold (bottom 0.0010000000000047748%): 82.0
# Level Outliers:
#     party_id     time level    job  spec map        date valid  valid_spec  \
# 67       131  오후 2:13    82     허밋  1750  붉켄  2024-12-18  True        True
# 168      285  오후 1:37   178   프리스트  1100  큰둥  2024-12-11  True        True
# 324      537  오전 1:32    82  크루세이더  2800  듀파  2024-12-16  True        True
#
#      spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 67       21.341463          18.275360       1750.0    1731.724640
# 168       6.179775           6.206757       1100.0    1093.793243
# 324      34.146341          32.285642       2800.0    2767.714358
#
#      avg_distance_per_job
# 67            2127.109256
# 168            886.793243
# 324           3817.596711
# Filtering out the top 99.9% outliers with distance greater than 2.4091842919345305
# tsne outliers:      party_id      time  level  job  spec  map        date valid  valid_spec  \
# 93         48  오전 12:35    154  용기사  None   큰둥  2024-12-19  True       False
# 1197        7   오후 4:33    155  용기사  None  갈림길  2024-12-12  True       False
# 2381       25  오전 12:19    115  용기사  None   검켄  2024-12-16  True       False
# 3371       89   오후 1:51    100   썬콜  None  망둥쩔  2024-12-17  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 93        34.726694          34.726694  5459.420156            NaN
# 1197      34.269116          34.269116  5420.056804            NaN
# 2381      35.369864          35.369864  4043.882433            NaN
# 3371       6.223686           6.223686   606.325323            NaN
#
#       avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 93             4411.364215  57.354027  -9.744566             3.053612
# 1197           4049.064217  60.124840 -14.263617             2.657267
# 2381           4700.830136  44.815285 -28.224176             3.501010
# 3371            887.776314 -11.133538   0.188093             3.073000
# Upper level threshold (top 99.999%): 169.99604
# Lower level threshold (bottom 0.0010000000000047748%): 83.00396000000002
# Level Outliers:
#     party_id      time level    job  spec  map        date valid  valid_spec  \
# 77        64  오전 12:50   170     허밋  3400  블와둥  2024-12-20  True        True
# 334      688   오전 1:40    83  크루세이더  2800   듀파  2024-12-16  True        True
#
#      spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 77        20.00000          18.366635       3400.0    3381.633365
# 334       33.73494          32.285642       2800.0    2767.714358
#
#      avg_distance_per_job
# 77            2302.433365
# 334           3817.596711
# Combined raw data saved as 'data/output/df.csv'
# Combined processed data saved as 'data/output/processed_df.csv'

# %%
df
# Out:
#      party_id      time  level   job  spec   map        date  valid  \
# 0           1  오전 12:33     88    허밋  None    붉켄  2024-12-19   True
# 1           1  오전 12:33    101   레인저  None    붉켄  2024-12-19   True
# 2           2  오전 12:33     90    허밋  None    붉켄  2024-12-19   True
# 3           2  오전 12:33     99    허밋  None    붉켄  2024-12-19   True
# 4           2  오전 12:33    105    썬콜   650    붉켄  2024-12-19   True
# ...       ...       ...    ...   ...   ...   ...         ...    ...
# 3536      292   오후 1:59    143   용기사  5000   블와둥  2024-12-17   True
# 3537      297   오후 1:59    119  프리스트  None    검켄  2024-12-17   True
# 3538      297   오후 1:59    134  프리스트  None    검켄  2024-12-17   True
# 3539      300   오후 1:59    123  프리스트  None  None  2024-12-17  False
# 3540      301   오후 1:59    112    허밋  None    검켄  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  \
# 0          False      18.446821          18.446821  1650.529707
# 1          False      22.312474          22.312474  2309.021500
# 2          False      18.446821          18.446821  1698.200636
# 3          False      18.446821          18.446821  1783.205935
# 4           True       6.190476           6.212019   650.000000
# ...          ...            ...                ...          ...
# 3536        True      34.965035          35.282984  5000.000000
# 3537       False       6.320755           6.320755   744.596610
# 3538       False       6.320755           6.320755   870.403211
# 3539       False       6.320755           6.320755   782.085858
# 3540       False      18.956725          18.956725  2085.927241
#
#       spec_distance  avg_distance_per_job  tsne_dim1  tsne_dim2  \
# 0               NaN           2415.678179 -15.352118 -56.793583
# 1               NaN           2402.687526 -17.742092 -38.215984
# 2               NaN           2415.678179 -15.770326 -55.970013
# 3               NaN           2415.678179 -17.377106 -52.889572
# 4        643.787981            793.121314 -34.458313 -26.768312
# ...             ...                   ...        ...        ...
# 3536    4964.717016           4940.217016  50.698814  -7.684323
# 3537            NaN            663.679245 -58.499069  34.309216
# 3538            NaN            663.679245 -55.367111  39.358418
# 3539            NaN            663.679245 -48.247066  17.878887
# 3540            NaN           2502.176609  25.771521  12.003955
#
#       distance_to_nearest
# 0                0.092767
# 1                0.058383
# 2                0.042240
# 3                0.091308
# 4                0.029664
# ...                   ...
# 3536             0.005686
# 3537             0.014003
# 3538             0.057536
# 3539             0.033263
# 3540             0.124041
#
# [3532 rows x 17 columns]

# %%
df_cr = df[(df['job'] == '크루세이더')]
df_cr
# Out:
#       party_id      time  level    job    spec  map        date  valid  \
# 10           4  오전 12:33    145  크루세이더     NaN  깊바협  2024-12-19   True
# 11           4  오전 12:33    158  크루세이더     NaN  깊바협  2024-12-19   True
# 15           7  오전 12:33    134  크루세이더     NaN  NaN  2024-12-19  False
# 59          33  오전 12:34    118  크루세이더     NaN   협동  2024-12-19   True
# 82          45  오전 12:35    126  크루세이더  4000.0  NaN  2024-12-19  False
# ...        ...       ...    ...    ...     ...  ...         ...    ...
# 3480       235   오후 1:56    117  크루세이더     NaN  NaN  2024-12-17  False
# 3487       242   오후 1:56    144  크루세이더  4800.0  블와둥  2024-12-17   True
# 3492       247   오후 1:57     97  크루세이더  3290.0   듀파  2024-12-17   True
# 3493       247   오후 1:57     97  크루세이더     NaN   듀파  2024-12-17   True
# 3520       290   오후 1:59    106  크루세이더     NaN  불어전  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  \
# 10         False      32.403057          32.403057  4684.949785
# 11         False      32.403057          32.403057  5224.102572
# 15         False      32.403057          32.403057  4220.010498
# 59         False      32.403057          32.403057  3811.131364
# 82          True      31.746032          32.403057  4000.000000
# ...          ...            ...                ...          ...
# 3480       False      32.663128          32.663128  3923.102553
# 3487        True      33.333333          32.663128  4800.000000
# 3492        True      33.917526          32.663128  3290.000000
# 3493       False      32.663128          32.663128  3108.763927
# 3520       False      32.663128          32.663128  3521.307591
#
#       spec_distance  avg_distance_per_job  tsne_dim1  tsne_dim2  \
# 10              NaN           4185.596943  15.176676 -61.154263
# 11              NaN           4185.596943  16.340010 -62.657608
# 15              NaN           4185.596943  31.026200 -50.001743
# 59              NaN           4185.596943  23.940691 -52.419754
# 82      3967.596943           4185.596943  30.602804 -49.321182
# ...             ...                   ...        ...        ...
# 3480            NaN           4151.765444  30.285727 -48.722130
# 3487    4767.336872           4151.765444  28.756393 -62.099007
# 3492    3257.336872           4151.765444  20.733458 -38.173878
# 3493            NaN           4151.765444  20.603804 -37.837760
# 3520            NaN           4151.765444  23.987160 -47.208150
#
#       distance_to_nearest
# 10               0.135434
# 11               0.033062
# 15               0.092035
# 59               0.049948
# 82               0.065331
# ...                   ...
# 3480             0.269384
# 3487             0.140158
# 3492             0.154787
# 3493             0.112369
# 3520             0.025925
#
# [291 rows x 17 columns]

# %%
processed_df_cr = processed_df[(processed_df['job'] == '크루세이더')]
print(len(processed_df_cr))
processed_df_cr.head()
# Out:
# 46
#     party_id      time  level    job  spec  map        date  valid  \
# 9         55  오전 12:36     95  크루세이더  3100   듀파  2024-12-19   True
# 16        70  오전 12:37    157  크루세이더  5040  블와둥  2024-12-19   True
# 27       125   오후 9:07    143  크루세이더  4772  깊바협  2024-12-19   True
# 29       138   오후 9:08     88  크루세이더  2900   듀파  2024-12-19   True
# 34       170   오후 9:09    119  크루세이더  3800   협동  2024-12-19   True
#
#     valid_spec  spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 9         True      32.631579          32.403057       3100.0    3067.596943
# 16        True      32.101911          32.403057       5040.0    5007.596943
# 27        True      33.370629          32.403057       4772.0    4739.596943
# 29        True      32.954545          32.403057       2900.0    2867.596943
# 34        True      31.932773          32.403057       3800.0    3767.596943
#
#     avg_distance_per_job
# 9            4185.596943
# 16           4185.596943
# 27           4185.596943
# 29           4185.596943
# 34           4185.596943

# %%
# %run eda.ipynb

map_dist(df)
map_dist(df_cr)
job_dist(df)
level_dist(df)
level_dist(df_cr)
level_dist_by_job(df)
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3532 entries, 0 to 3531
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   party_id              3532 non-null   int64
#  1   time                  3532 non-null   object
#  2   level                 3532 non-null   int64
#  3   job                   3532 non-null   object
#  4   spec                  463 non-null    float64
#  5   map                   3160 non-null   object
#  6   date                  3532 non-null   object
#  7   valid                 3532 non-null   bool
#  8   valid_spec            3532 non-null   bool
#  9   spec_by_level         3230 non-null   float64
#  10  avg_spec_by_level     3230 non-null   float64
#  11  spec_filled           3532 non-null   float64
#  12  spec_distance         463 non-null    float64
#  13  avg_distance_per_job  3230 non-null   float64
#  14  tsne_dim1             3532 non-null   float64
#  15  tsne_dim2             3532 non-null   float64
#  16  distance_to_nearest   3532 non-null   float64
# dtypes: bool(2), float64(9), int64(2), object(4)
# memory usage: 420.9+ KB
# None
#
# Data Overview:
#    party_id      time  level  job   spec map        date  valid  valid_spec  \
# 0         1  오전 12:33     88   허밋    NaN  붉켄  2024-12-19   True       False
# 1         1  오전 12:33    101  레인저    NaN  붉켄  2024-12-19   True       False
# 2         2  오전 12:33     90   허밋    NaN  붉켄  2024-12-19   True       False
# 3         2  오전 12:33     99   허밋    NaN  붉켄  2024-12-19   True       False
# 4         2  오전 12:33    105   썬콜  650.0  붉켄  2024-12-19   True        True
#
#    spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 0      18.446821          18.446821  1650.529707            NaN
# 1      22.312474          22.312474  2309.021500            NaN
# 2      18.446821          18.446821  1698.200636            NaN
# 3      18.446821          18.446821  1783.205935            NaN
# 4       6.190476           6.212019   650.000000     643.787981
#
#    avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 0           2415.678179 -15.352118 -56.793583             0.092767
# 1           2402.687526 -17.742092 -38.215984             0.058383
# 2           2415.678179 -15.770326 -55.970013             0.042240
# 3           2415.678179 -17.377106 -52.889572             0.091308
# 4            793.121314 -34.458313 -26.768312             0.029664
#
# Map Frequency:
# map
# 협동     429
# 불어전    394
# 망용둥    383
# 듀파     325
# 블와둥    297
# 붉켄     227
# 깊바협    185
# 검켄     165
# 레와둥    155
# 산양     115
# 하둥      99
# 오징어     87
# 갈림길     68
# 와협      57
# 망둥쩔     50
# 푸켄      37
# 물어전     33
# 위둥      24
# 큰둥      15
# 남둥      15
# Name: count, dtype: int64
#
# Job Frequency:
# job
# 프리스트     906
# 허밋       720
# 썬콜       470
# 용기사      430
# 레인저      349
# 크루세이더    291
# 불독       130
# 저격수      118
# 나이트       99
# 시프        19
# Name: count, dtype: int64
#
# Level Statistics by Job:
#        count        mean        std   min    25%    50%     75%    max
# job
# 나이트     99.0  117.676768  18.713647  82.0  106.5  120.0  130.00  157.0
# 레인저    349.0  117.656160  30.723495   0.0  107.0  121.0  134.00  173.0
# 불독     130.0  130.515385  25.188663   0.0  117.0  130.5  149.00  173.0
# 시프      19.0  116.000000  13.630032  92.0  112.0  118.0  123.00  140.0
# 썬콜     470.0  122.131915  24.126701   0.0  109.0  124.5  138.00  169.0
# 용기사    430.0  127.290698  26.273293   0.0  114.0  128.5  146.00  175.0
# 저격수    118.0  118.033898  19.528604  83.0  102.0  118.0  133.00  160.0
# 크루세이더  291.0  126.635739  25.927444   0.0  111.0  127.0  144.50  175.0
# 프리스트   906.0  113.210817  20.411965   0.0   99.0  112.0  127.75  168.0
# 허밋     720.0  124.061111  25.056523   0.0  109.0  124.0  142.00  173.0

# %%
# %run data_visualization.ipynb

job="크루세이더"
jobs=["용기사", "크루세이더"]
input_map="블와둥"
input_maps=["블와둥", "협동", "깊바협"]
start_level=120
end_level=160
input_level=145

#1 직업별 평균 스펙
# average_spec_by_job(df)
#2 맵별 직업 분포
# plot_job_frequency_by_map(df)
#3 특정 직업, 레벨(optional), 스펙_filled
plot_level_spec_with_regression(df, job)
plot_level_spec_with_regression(df, job, input_level=input_level, use_spec_filled=True)
#4 레벨+-5의 스펙 회귀
# plot_level_spec_with_regression_by_level(df, job, input_level)
#5 특정 직업의 레벨 별 맵 분포
plot_level_by_map_by_job(df, job)
#6 특정직업의 레벨별 사냥터 분포(5%+)
plot_level_distribution_by_job_and_map(df, job)
#7 특정 직업의 레벨별 맵 히트맵
plot_map_level_heatmap_for_job(df, job)
#8 특정직업의 레벨 범위별 사냥터 히트맵 
plot_map_frequency_by_level_range(df, job)
#9 맵별 스펙 기재 여부
visualize_spec_validity_by_map(df, job='all')
visualize_spec_validity_by_map(df, job=job)
#10 직업별 스펙 기재 여부, job optional
visualize_spec_validity_by_jobs(df, jobs=None)
#11 날짜별 맵 사용 비율
# visualize_map_distribution_by_date(df)
# visualize_map_distribution_by_date(df_il)
#12 직업별 레벨(범위 설정 가능)당 스펙
# visualize_level_spec_comparison(df, jobs=None, start_level=None, end_level=None)
#13 직업별 레벨에 따른 스공과 맵, 회귀
# plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#14 맵 사용빈도 변화 추이
visualize_map_percentage_change(df_il, "불어전")
# visualize_map_percentage_change(df_il, input_map)
#15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
# plot_level_spec_distribution_of_job_and_map(df, "불어전", job, use_spec_filled=False)
plot_level_spec_distribution_of_job_and_map(df, input_map, job, use_spec_filled=False)
#16 특정 직업의 맵별분포와 레벨, 스펙 회귀
plot_level_spec_distribution_of_job(df, job)
plot_level_spec_distribution_of_job(df, "허밋")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 41
#      32 visualize_spec_validity_by_jobs(df, jobs=None)
#      33 #11 날짜별 맵 사용 비율
#      34 # visualize_map_distribution_by_date(df)
#      35 # visualize_map_distribution_by_date(df_il)
#    (...)
#      39 # plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#      40 #14 맵 사용빈도 변화 추이
# ---> 41 visualize_map_percentage_change(df_il, "불어전")
#      42 # visualize_map_percentage_change(df_il, input_map)
#      43 #15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
#      44 # plot_level_spec_distribution_of_job_and_map(df, "불어전", job, use_spec_filled=False)
#      45 plot_level_spec_distribution_of_job_and_map(df, input_map, job, use_spec_filled=False)
#
# NameError: name 'df_il' is not defined

# %%
# %run modeling.ipynb

recommend_map_knn(100, job, level_range=5)
recommend_map_svd(100, job, level_range=5)

recommend_map_knn(120, job, level_range=5)
recommend_map_svd(120, job, level_range=5)

recommend_map_knn(140, job, level_range=5)
recommend_map_svd(140, job, level_range=5)

tsne_visualization(df)
tsne_visualization(df, jobs=[job])
