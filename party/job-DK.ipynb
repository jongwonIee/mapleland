# %%
# %run data_loading.ipynb
# Out:
# Data saved as data/output/1219.csv
# Processed valid data saved as data/output/1219_processed.csv
# Data saved as data/output/1218.csv
# Processed valid data saved as data/output/1218_processed.csv
# Data saved as data/output/1220.csv
# Processed valid data saved as data/output/1220_processed.csv
# Data saved as data/output/1221.csv
# Processed valid data saved as data/output/1221_processed.csv
# Data saved as data/output/1213.csv
# Processed valid data saved as data/output/1213_processed.csv
# Data saved as data/output/1212.csv
# Processed valid data saved as data/output/1212_processed.csv
# Data saved as data/output/1211.csv
# Processed valid data saved as data/output/1211_processed.csv
# Data saved as data/output/1215.csv
# Processed valid data saved as data/output/1215_processed.csv
# Data saved as data/output/1214.csv
# Processed valid data saved as data/output/1214_processed.csv
# Data saved as data/output/1216.csv
# Processed valid data saved as data/output/1216_processed.csv
# Data saved as data/output/1217.csv
# Processed valid data saved as data/output/1217_processed.csv
# Upper level threshold (top 99.99%): 176.9526999999989
# Lower level threshold (bottom 0.010000000000005116%): 80.0
# Level Outliers:
#      party_id      time level   job  spec  map        date valid  valid_spec  \
# 350       198   오후 9:10    80    허밋  None  망용둥  2024-12-19  True       False
# 1317      228   오후 4:38    80  프리스트  None  망둥쩔  2024-12-12  True       False
# 1473      100   오후 1:16    80   나이트  None   하둥  2024-12-11  True       False
# 1606      285   오후 1:37   178  프리스트  1100   큰둥  2024-12-11  True        True
# 2519      188  오전 12:46    80    썬콜  None   하둥  2024-12-16  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 350       18.446821          18.446821  1432.763806            NaN
# 1317            NaN                NaN          NaN            NaN
# 1473      30.412222          30.412222  2504.623115            NaN
# 1606       6.179775           6.206757  1100.000000    1093.793243
# 2519       6.226383           6.226383   491.174917            NaN
#
#       avg_distance_per_job
# 350            2415.678179
# 1317                   NaN
# 1473           4429.587778
# 1606            886.793243
# 2519            804.696694
# Upper level threshold (top 99.999%): 177.96807999999965
# Lower level threshold (bottom 0.0010000000000047748%): 82.0
# Level Outliers:
#     party_id     time level    job  spec map        date valid  valid_spec  \
# 67       131  오후 2:13    82     허밋  1750  붉켄  2024-12-18  True        True
# 168      285  오후 1:37   178   프리스트  1100  큰둥  2024-12-11  True        True
# 324      537  오전 1:32    82  크루세이더  2800  듀파  2024-12-16  True        True
#
#      spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 67       21.341463          18.275360       1750.0    1731.724640
# 168       6.179775           6.206757       1100.0    1093.793243
# 324      34.146341          32.285642       2800.0    2767.714358
#
#      avg_distance_per_job
# 67            2139.224640
# 168            886.793243
# 324           3817.596711
# Filtering out the top 99.9% outliers with distance greater than 2.969498834228242
# tsne outliers:      party_id      time  level  job  spec  map        date valid  valid_spec  \
# 689        43  오전 12:38   93.0   시프  None   듀파  2024-12-20  True       False
# 1835       32   오후 3:48  139.0   시프  None   듀파  2024-12-15  True       False
# 2345       25  오전 12:19  115.0  용기사  None   검켄  2024-12-16  True       False
# 3323       89   오후 1:51  100.0   썬콜  None  망둥쩔  2024-12-17  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 689             NaN                NaN  2199.055186            NaN
# 1835            NaN                NaN  2199.055186            NaN
# 2345      35.369864          35.369864  3998.402742            NaN
# 3323       6.223686           6.223686   612.503977            NaN
#
#       avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 689                    NaN  -3.747382 -15.954179             5.649643
# 1835                   NaN  -0.954357 -35.617123             5.518259
# 2345           4700.830136  32.439598 -39.875767             3.120863
# 3323            887.776314 -18.594862  52.127903             3.253519
# Filtering out the top 99.9% outliers with distance greater than 2.5237361010752326
# tsne outliers:     party_id     time  level  job  spec  map        date valid  valid_spec  \
# 320      500  오전 1:22  134.0  저격수  3330  망용둥  2024-12-16  True        True
#
#      spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 320      24.850746           23.83578       3330.0     3306.16422
#
#      avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 320            2628.66422   2.511012  -0.184198               2.7965
# Combined raw data saved as 'data/output/df.csv'
# Combined processed data saved as 'data/output/processed_df.csv'

# %%
df_dk = df[(df['job'] == '용기사')]
df_dk
# Out:
#      party_id      time  level  job  spec  map        date valid  valid_spec  \
# 16          8  오전 12:33   83.0  용기사  None   하둥  2024-12-19  True       False
# 18          9  오전 12:33  122.0  용기사  None   협동  2024-12-19  True       False
# 36         18  오전 12:34  124.0  용기사  4200  블와둥  2024-12-19  True        True
# 42         23  오전 12:34  126.0  용기사  None  블와둥  2024-12-19  True       False
# 44         24  오전 12:34  148.0  용기사  None   협동  2024-12-19  True       False
# ...       ...       ...    ...  ...   ...  ...         ...   ...         ...
# 3429      221   오후 1:55   97.0  용기사  None   하둥  2024-12-17  True       False
# 3449      246   오후 1:56  126.0  용기사  4100   듀파  2024-12-17  True        True
# 3456      255   오후 1:57  156.0  용기사  None  블와둥  2024-12-17  True       False
# 3468      263   오후 1:57  107.0  용기사  3400  불어전  2024-12-17  True        True
# 3487      292   오후 1:59  143.0  용기사  5000  블와둥  2024-12-17  True        True
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 16        34.726694          34.726694  2804.353748            NaN
# 18        34.726694          34.726694  4202.102375            NaN
# 36        33.870968          34.726694  4200.000000    4165.273306
# 42        34.726694          34.726694  4348.229699            NaN
# 44        34.726694          34.726694  5001.453305            NaN
# ...             ...                ...          ...            ...
# 3429      35.282984          35.282984  3447.055715            NaN
# 3449      32.539683          35.282984  4100.000000    4064.717016
# 3456      35.282984          35.282984  5577.927218            NaN
# 3468      31.775701          35.282984  3400.000000    3364.717016
# 3487      34.965035          35.282984  5000.000000    4964.717016
#
#       avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 16             4411.364215  29.201845 -49.277378             0.070640
# 18             4411.364215  64.427078 -36.343880             0.302689
# 36             4411.364215  37.516624 -27.733282             0.193791
# 42             4411.364215  38.105209 -27.301579             0.235195
# 44             4411.364215  61.652222 -30.457821             0.179011
# ...                    ...        ...        ...                  ...
# 3429           4940.217016  30.950455 -49.892132             0.145842
# 3449           4940.217016  29.373096 -39.286442             0.001757
# 3456           4940.217016  51.376766 -23.167986             0.133740
# 3468           4940.217016  36.640144 -37.625340             0.071339
# 3487           4940.217016  45.328995 -24.898813             0.056567
#
# [425 rows x 17 columns]

# %%
processed_df_dk = processed_df[(processed_df['job'] == '용기사')]
print(len(processed_df_dk))
processed_df_dk.head()
# Out:
# 56
#    party_id      time  level  job  spec  map        date valid  valid_spec  \
# 3        18  오전 12:34  124.0  용기사  4200  블와둥  2024-12-19  True        True
# 5        41  오전 12:35  127.0  용기사  4370  블와둥  2024-12-19  True        True
# 11       57  오전 12:36  119.0  용기사  4100   듀파  2024-12-19  True        True
# 13       67  오전 12:36  110.0  용기사  3700   하둥  2024-12-19  True        True
# 14       70  오전 12:37  157.0  용기사  5650  블와둥  2024-12-19  True        True
#
#     spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 3       33.870968          34.726694       4200.0    4165.273306
# 5       34.409449          34.726694       4370.0    4335.273306
# 11      34.453782          34.726694       4100.0    4065.273306
# 13      33.636364          34.726694       3700.0    3665.273306
# 14      35.987261          34.726694       5650.0    5615.273306
#
#     avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 3            4411.364215  27.569923 -16.980835             0.206580
# 5            4411.364215  27.250263 -17.250257             0.350228
# 11           4411.364215  27.041603 -11.096073             0.139162
# 13           4411.364215  29.771729 -12.358700             0.019333
# 14           4411.364215  24.060682 -19.721867             0.407334

# %%
# %run eda.ipynb

map_dist(df)
map_dist(df_dk)
job_dist(df)
level_dist(df)
level_dist(df_dk)
level_dist_by_job(df)
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3483 entries, 0 to 3482
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   party_id              3483 non-null   int64
#  1   time                  3483 non-null   object
#  2   level                 3483 non-null   float64
#  3   job                   3483 non-null   object
#  4   spec                  462 non-null    float64
#  5   map                   3124 non-null   object
#  6   date                  3483 non-null   object
#  7   valid                 3483 non-null   bool
#  8   valid_spec            3483 non-null   bool
#  9   spec_by_level         3186 non-null   float64
#  10  avg_spec_by_level     3186 non-null   float64
#  11  spec_filled           3483 non-null   float64
#  12  spec_distance         462 non-null    float64
#  13  avg_distance_per_job  3186 non-null   float64
#  14  tsne_dim1             3483 non-null   float64
#  15  tsne_dim2             3483 non-null   float64
#  16  distance_to_nearest   3483 non-null   float64
# dtypes: bool(2), float64(10), int64(1), object(4)
# memory usage: 415.1+ KB
# None
#
# Data Overview:
#    party_id      time  level  job   spec map        date  valid  valid_spec  \
# 0         1  오전 12:33   88.0   허밋    NaN  붉켄  2024-12-19   True       False
# 1         1  오전 12:33  101.0  레인저    NaN  붉켄  2024-12-19   True       False
# 2         2  오전 12:33   90.0   허밋    NaN  붉켄  2024-12-19   True       False
# 3         2  오전 12:33   99.0   허밋    NaN  붉켄  2024-12-19   True       False
# 4         2  오전 12:33  105.0   썬콜  650.0  붉켄  2024-12-19   True        True
#
#    spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 0      18.446821          18.446821  1624.999400            NaN
# 1      22.312474          22.312474  2297.087164            NaN
# 2      18.446821          18.446821  1640.179897            NaN
# 3      18.446821          18.446821  1792.346041            NaN
# 4       6.190476           6.212019   650.000000     643.787981
#
#    avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 0           2415.678179 -11.992740  -9.918794             0.347529
# 1           2402.687526 -15.874035 -30.524767             0.039511
# 2           2415.678179 -11.359418  -9.375133             0.150740
# 3           2415.678179  -8.456456  -7.198072             0.247934
# 4            793.121314 -17.962490  46.753246             0.017037
#
# Map Frequency:
# map
# 협동     426
# 불어전    386
# 망용둥    377
# 듀파     323
# 블와둥    297
# 붉켄     226
# 깊바협    183
# 검켄     165
# 레와둥    147
# 산양     114
# 하둥      99
# 오징어     87
# 갈림길     69
# 와협      56
# 망둥쩔     44
# 푸켄      37
# 물어전     33
# 위둥      24
# 큰둥      16
# 남둥      15
# Name: count, dtype: int64
#
# Job Frequency:
# job
# 프리스트     900
# 허밋       712
# 썬콜       462
# 용기사      425
# 레인저      334
# 크루세이더    288
# 불독       128
# 저격수      118
# 나이트       99
# 시프        17
# Name: count, dtype: int64
#
# Level Statistics by Job:
#        count        mean        std   min    25%    50%     75%    max
# job
# 나이트     99.0  117.676768  18.713647  82.0  106.5  120.0  130.00  157.0
# 레인저    334.0  122.940120  18.300035  84.0  109.0  122.0  134.00  173.0
# 불독     128.0  132.554688  19.287632  87.0  117.0  131.0  149.25  173.0
# 시프      17.0  116.000000  11.953033  92.0  114.0  118.0  123.00  140.0
# 썬콜     462.0  124.246753  18.134701  84.0  110.0  125.0  138.00  169.0
# 용기사    425.0  129.515294  20.723366  81.0  115.0  129.0  146.00  175.0
# 저격수    118.0  118.033898  19.528604  83.0  102.0  118.0  133.00  160.0
# 크루세이더  288.0  127.954861  22.580588  82.0  111.0  127.0  145.00  175.0
# 프리스트   900.0  113.965556  18.257031  81.0   99.0  112.0  128.00  168.0
# 허밋     712.0  125.455056  21.442251  81.0  110.0  124.0  142.00  173.0

# %%
# %run data_visualization.ipynb

job="용기사"
jobs=["용기사", "크루세이더"]
input_map="블와둥"
input_maps=["블와둥", "협동", "깊바협"]
start_level=120
end_level=160
input_level=145

#1 직업별 평균 스펙
# average_spec_by_job(df)
#2 맵별 직업 분포
# plot_job_frequency_by_map(df)
#3 특정 직업, 레벨(optional), 스펙_filled
plot_level_spec_with_regression(df, job)
plot_level_spec_with_regression(df, job, input_level=input_level, use_spec_filled=True)
#4 레벨+-5의 스펙 회귀
# plot_level_spec_with_regression_by_level(df, job, input_level)
#5 특정 직업의 레벨 별 맵 분포
plot_level_by_map_by_job(df, job)
#6 특정직업의 레벨별 사냥터 분포(5%+)
plot_level_distribution_by_job_and_map(df, job)
#7 특정 직업의 레벨별 맵 히트맵
plot_map_level_heatmap_for_job(df, job)
#8 특정직업의 레벨 범위별 사냥터 히트맵 
plot_map_frequency_by_level_range(df, job)
#9 맵별 스펙 기재 여부
visualize_spec_validity_by_map(df, job='all')
visualize_spec_validity_by_map(df, job=job)
#10 직업별 스펙 기재 여부, job optional
visualize_spec_validity_by_jobs(df, jobs=None)
#11 날짜별 맵 사용 비율
# visualize_map_distribution_by_date(df)
# visualize_map_distribution_by_date(df_il)
#12 직업별 레벨(범위 설정 가능)당 스펙
# visualize_level_spec_comparison(df, jobs=None, start_level=None, end_level=None)
#13 직업별 레벨에 따른 스공과 맵, 회귀
# plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#14 맵 사용빈도 변화 추이
visualize_map_percentage_change(df_dk, input_map)
# visualize_map_percentage_change(df_il, input_map)
#15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
plot_level_spec_distribution_of_job_and_map(df, input_map, job, use_spec_filled=True)
#16 특정 직업의 맵별분포와 레벨, 스펙 회귀
plot_level_spec_distribution_of_job(df, job)

# %%
# %run modeling.ipynb

recommend_map_knn(100, job, level_range=5)
recommend_map_svd(100, job, level_range=5)

recommend_map_knn(120, job, level_range=5)
recommend_map_svd(120, job, level_range=5)

recommend_map_knn(140, job, level_range=5)
recommend_map_svd(140, job, level_range=5)

process_tsne(df)
process_tsne(df_dk)
# Out:
# Similarity scores for recommended maps:
# Map: 하둥, Score: 4.732382838549031
# Map: 갈림길, Score: 7.685223884186696
# Recommended Maps and Scores: ['하둥', '갈림길']
# Unique maps after preprocessing:
# ['하둥' '협동' '블와둥' '산양' '듀파']
# Similarity scores for recommended maps:
# Map: 블와둥, Score: 0.49999999999999994
# Map: 듀파, Score: 0.4999999999999997
# Map: 산양, Score: 9.107298248878237e-18
# Recommended Maps: Index(['블와둥', '듀파', '산양'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 듀파, Score: 5.6279044402538
# Map: 블와둥, Score: 7.144341006435866
# Recommended Maps and Scores: ['듀파', '블와둥']
# Unique maps after preprocessing:
# ['하둥' '협동' '블와둥' '산양' '듀파']
# Similarity scores for recommended maps:
# Map: 블와둥, Score: 0.3333333333333333
# Map: 산양, Score: 0.3333333333333332
# Map: 듀파, Score: 0.3333333333333331
# Recommended Maps: Index(['블와둥', '산양', '듀파'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 불어전, Score: 4.60851981315994
# Map: 위둥, Score: 9.6304693830607
# Map: 블와둥, Score: 20.801151485650227
# Recommended Maps and Scores: ['불어전', '위둥', '블와둥']
# Unique maps after preprocessing:
# ['하둥' '협동' '블와둥' '산양' '듀파']
# Similarity scores for recommended maps:
# Map: 블와둥, Score: 0.49999999999999994
# Map: 산양, Score: 0.49999999999999983
# Map: 듀파, Score: -1.1709383462843448e-17
# Recommended Maps: Index(['블와둥', '산양', '듀파'], dtype='object', name='map')
