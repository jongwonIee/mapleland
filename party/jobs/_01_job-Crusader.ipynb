# %%
import os
os.chdir('/Users/lee/PythonProjects/mapleland/party')

# %%
# %run _01_data_loading.ipynb
# Out:
# Data saved as data/output/1227.csv
# Processed valid data saved as data/output/1227_processed.csv
# Data saved as data/output/1219.csv
# Processed valid data saved as data/output/1219_processed.csv
# Data saved as data/output/1218.csv
# Processed valid data saved as data/output/1218_processed.csv
# Data saved as data/output/1224.csv
# Processed valid data saved as data/output/1224_processed.csv
# Data saved as data/output/1220.csv
# Processed valid data saved as data/output/1220_processed.csv
# Data saved as data/output/1221.csv
# Processed valid data saved as data/output/1221_processed.csv
# Data saved as data/output/1223.csv
# Processed valid data saved as data/output/1223_processed.csv
# Data saved as data/output/1222.csv
# Processed valid data saved as data/output/1222_processed.csv
# Data saved as data/output/1213.csv
# Processed valid data saved as data/output/1213_processed.csv
# Data saved as data/output/1212.csv
# Processed valid data saved as data/output/1212_processed.csv
# Data saved as data/output/1211.csv
# Processed valid data saved as data/output/1211_processed.csv
# Data saved as data/output/1215.csv
# Processed valid data saved as data/output/1215_processed.csv
# Data saved as data/output/1214.csv
# Processed valid data saved as data/output/1214_processed.csv
# Data saved as data/output/1216.csv
# Processed valid data saved as data/output/1216_processed.csv
# Data saved as data/output/1217.csv
# Processed valid data saved as data/output/1217_processed.csv
# Combined raw data saved as 'data/output/df.csv'
# Combined processed data saved as 'data/output/processed_df.csv'

# %%
df_cr = df[(df['job'] == '크루세이더')]
df_cr
# Out:
#      party_id     time level    job  spec   map        date  valid  \
# 1           2  오후 8:51   109  크루세이더  None    듀파  2024-12-27   True
# 29         19  오후 8:52   128  크루세이더  4200   깊바협  2024-12-27   True
# 32         22  오후 8:52   112  크루세이더  None   깊바협  2024-12-27   True
# 34         22  오후 8:52   110  크루세이더  None   깊바협  2024-12-27   True
# 47         35  오후 8:53   144  크루세이더  None   깊바협  2024-12-27   True
# ...       ...      ...   ...    ...   ...   ...         ...    ...
# 4945      235  오후 1:56   117  크루세이더  None  None  2024-12-17  False
# 4952      242  오후 1:56   144  크루세이더  4800   블와둥  2024-12-17   True
# 4957      247  오후 1:57    97  크루세이더  3290    듀파  2024-12-17   True
# 4958      247  오후 1:57    97  크루세이더  None    듀파  2024-12-17   True
# 4985      290  오후 1:59   106  크루세이더  None   불어전  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled
# 1          False      33.273266          33.273266  3727.659606
# 29          True      32.812500          33.273266  4200.000000
# 32         False      33.273266          33.273266  3681.795791
# 34         False      33.273266          33.273266  3574.973205
# 47         False      33.273266          33.273266  4813.635149
# ...          ...            ...                ...          ...
# 4945       False      32.663128          32.663128  3790.676623
# 4952        True      33.333333          32.663128  4800.000000
# 4957        True      33.917526          32.663128  3290.000000
# 4958       False      32.663128          32.663128  3081.556098
# 4985       False      32.663128          32.663128  3515.585457
#
# [411 rows x 12 columns]

# %%
processed_df_cr = processed_df[(processed_df['job'] == '크루세이더')]
print(len(processed_df_cr))
processed_df_cr.head()
# Out:
# 62
#    party_id     time level    job  spec  map        date valid  valid_spec  \
# 1        19  오후 8:52   128  크루세이더  4200  깊바협  2024-12-27  True        True
# 6        41  오후 8:53    99  크루세이더  3300   듀파  2024-12-27  True        True
# 9        42  오후 8:53   108  크루세이더  3400   듀파  2024-12-27  True        True
# 34      191  오후 9:07    90  크루세이더  3000   듀파  2024-12-27  True        True
# 45      263  오후 9:09   129  크루세이더  4200  깊바협  2024-12-27  True        True
#
#     spec_by_level  avg_spec_by_level  spec_filled
# 1       32.812500          33.273266       4200.0
# 6       33.333333          33.273266       3300.0
# 9       31.481481          33.273266       3400.0
# 34      33.333333          33.273266       3000.0
# 45      32.558140          33.273266       4200.0

# %%
# %run _02_eda.ipynb

map_dist(df)
map_dist(df_cr)
job_dist(df)
level_dist(df)
level_dist(df_cr)
level_dist_by_job(df)
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4997 entries, 0 to 4996
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   party_id           4997 non-null   int64
#  1   time               4997 non-null   object
#  2   level              4997 non-null   int64
#  3   job                4997 non-null   object
#  4   spec               703 non-null    float64
#  5   map                4467 non-null   object
#  6   date               4997 non-null   object
#  7   valid              4997 non-null   bool
#  8   valid_spec         4997 non-null   bool
#  9   spec_by_level      4645 non-null   float64
#  10  avg_spec_by_level  4645 non-null   float64
#  11  spec_filled        4645 non-null   float64
# dtypes: bool(2), float64(4), int64(2), object(4)
# memory usage: 400.3+ KB
# None
#
# Data Overview:
#    party_id     time  level    job  spec  map        date  valid  valid_spec  \
# 0         1  오후 8:51    109    용기사   NaN   협동  2024-12-27   True       False
# 1         2  오후 8:51    109  크루세이더   NaN   듀파  2024-12-27   True       False
# 2         2  오후 8:51     89     허밋   NaN   듀파  2024-12-27   True       False
# 3         2  오후 8:51     97   프리스트   NaN   듀파  2024-12-27   True       False
# 4         3  오후 8:51    135   프리스트   NaN  불어전  2024-12-27   True       False
#
#    spec_by_level  avg_spec_by_level  spec_filled
# 0      36.538611          36.538611  3957.392721
# 1      33.273266          33.273266  3727.659606
# 2      19.182637          19.182637  1726.208701
# 3       6.330342           6.330342   605.384845
# 4       6.330342           6.330342   873.382498
#
# Map Frequency:
# map
# 협동     616
# 망용둥    544
# 불어전    524
# 듀파     460
# 블와둥    453
# 붉켄     336
# 깊바협    276
# 검켄     230
# 레와둥    201
# 산양     155
# 오징어    126
# 하둥     118
# 갈림길     85
# 망둥쩔     85
# 와협      66
# 푸켄      60
# 물어전     49
# 위둥      38
# 큰둥      23
# 남둥      22
# Name: count, dtype: int64
#
# Job Frequency:
# job
# 프리스트     1264
# 허밋       1042
# 썬콜        670
# 용기사       621
# 레인저       480
# 크루세이더     411
# 불독        173
# 저격수       171
# 나이트       136
# 시프         29
# Name: count, dtype: int64
#
# Level Statistics by Job:
#         count        mean        std   min     25%    50%    75%    max
# job
# 나이트     136.0  118.786765  18.058509  80.0  107.75  121.0  129.0  161.0
# 레인저     480.0  123.497917  18.519639  80.0  110.00  123.0  137.0  173.0
# 불독      173.0  132.393064  18.830219  87.0  117.00  132.0  147.0  175.0
# 시프       29.0  118.482759  15.317172  92.0  110.00  118.0  125.0  159.0
# 썬콜      670.0  123.144776  17.843572  80.0  109.00  123.0  136.0  169.0
# 용기사     621.0  128.671498  19.955393  81.0  115.00  129.0  145.0  175.0
# 저격수     171.0  116.953216  18.923317  83.0  102.00  116.0  132.0  160.0
# 크루세이더   411.0  126.690998  21.942483  82.0  111.00  126.0  144.0  175.0
# 프리스트   1264.0  114.220728  18.259878  80.0   99.00  113.0  127.0  178.0
# 허밋     1042.0  124.390595  21.445416  80.0  108.25  123.0  141.0  175.0

# %%
# %run _03_data_visualization.ipynb

job="크루세이더"
jobs=["크루세이더", "용기사"]
input_map="블와둥"
input_maps=["블와둥", "협동", "깊바협"]
start_level=120
end_level=160
input_level=145

#1 직업별 평균 스펙
# average_spec_by_job(df)
#2 맵별 직업 분포
# plot_job_frequency_by_map(df)
#3 특정 직업, 레벨(optional), 스펙_filled
plot_level_spec_with_regression(df, job)
plot_level_spec_with_regression(df, job, input_level=input_level, use_spec_filled=True)
#4 레벨+-5의 스펙 회귀
# plot_level_spec_with_regression_by_level(df, job, input_level)
#5 특정 직업의 레벨 별 맵 분포
plot_level_by_map_by_job(df, job)
#6 특정직업의 레벨별 사냥터 분포(5%+)
plot_level_distribution_by_job_and_map(df, job)
#7 특정 직업의 레벨별 맵 히트맵
plot_map_level_heatmap_for_job(df, job)
#8 특정직업의 레벨 범위별 사냥터 히트맵 
plot_map_frequency_by_level_range(df, job)
#9 맵별 스펙 기재 여부
visualize_spec_validity_by_map(df, job='all')
#10 직업별 스펙 기재 여부, job optional
visualize_spec_validity_by_jobs(df)
#11 날짜별 맵 사용 비율
# visualize_map_distribution_by_date(df)
visualize_map_distribution_by_date(df_cr)
#12 직업별 레벨(범위 설정 가능)당 스펙
# visualize_level_spec_comparison(df, jobs=None, start_level=None, end_level=None)
#13 직업별 레벨에 따른 스공과 맵, 회귀
# plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#14 맵 사용빈도 변화 추이
visualize_map_percentage_change(df_cr, input_maps[0])
visualize_map_percentage_change(df_cr, input_maps[1])
visualize_map_percentage_change(df_cr, input_maps[2])
# visualize_map_percentage_change(df_il, input_map)
#15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
plot_level_spec_distribution_of_job_and_map(df, input_maps[0], job, use_spec_filled=True)
plot_level_spec_distribution_of_job_and_map(df, input_maps[1], job, use_spec_filled=True)
plot_level_spec_distribution_of_job_and_map(df, input_maps[2], job, use_spec_filled=True)
#16 특정 직업의 맵별분포와 레벨, 스펙 회귀
plot_level_spec_distribution_of_job(df, job, use_spec_filled=False)

# %%
# %run _04_modeling.ipynb

recommend_map_knn(100, job, level_range=5)
recommend_map_svd(100, job, level_range=5)

recommend_map_knn(120, job, level_range=5)
recommend_map_svd(120, job, level_range=5)

recommend_map_knn(140, job, level_range=5)
recommend_map_svd(140, job, level_range=5)
# Out:
# Filtering out the top 99.9% outliers with distance greater than 2.0999318840500005
#       party_id      time  level  job    spec  map        date  valid  \
# 1307       245  오전 12:57  120.0   시프     NaN   산양  2024-12-24   True
# 2453       238   오후 9:48   96.0  용기사  3600.0   붉켄  2024-12-22   True
# 3335        29   오후 3:48  105.0   불독     NaN  NaN  2024-12-15  False
# 3850        25  오전 12:19  115.0  용기사     NaN   검켄  2024-12-16   True
# 4446       677   오전 1:39  144.0   썬콜     NaN  블와둥  2024-12-16   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  tsne_dim1  \
# 1307       False            NaN                NaN  2209.362009  15.634353
# 2453        True      37.500000          36.396941  3600.000000  37.259518
# 3335       False            NaN                NaN  2209.362009  -8.807467
# 3850       False      35.369864          35.369864  4142.848643  61.003422
# 4446       False       6.226383           6.226383   914.481994  11.609561
#
#       tsne_dim2  distance_to_nearest
# 1307   9.304316             2.379229
# 2453 -53.329742             2.280587
# 3335   2.738491             3.365109
# 3850 -34.797569             2.422559
# 4446  69.185684             2.206656
# Similarity scores for recommended maps:
# Map: 듀파, Score: 6.7550287425142415
# Recommended Maps and Scores: ['듀파']
# Unique maps after preprocessing:
# ['듀파' '깊바협' '오징어' '협동' '블와둥']
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 0.33333333333333315
# Map: 듀파, Score: 0.3333333333333331
# Map: 블와둥, Score: 0.33333333333333304
# Recommended Maps: Index(['깊바협', '듀파', '블와둥'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 블와둥, Score: 4.184832758254998
# Map: 듀파, Score: 7.8149267054257745
# Map: 오징어, Score: 8.758272372865894
# Recommended Maps and Scores: ['블와둥', '듀파', '오징어']
# Unique maps after preprocessing:
# ['듀파' '깊바협' '오징어' '협동' '블와둥']
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 0.33333333333333315
# Map: 듀파, Score: 0.3333333333333331
# Map: 블와둥, Score: 0.33333333333333304
# Recommended Maps: Index(['깊바협', '듀파', '블와둥'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 11.678370031867763
# Map: 블와둥, Score: 12.658836122683384
# Recommended Maps and Scores: ['깊바협', '블와둥']
# Unique maps after preprocessing:
# ['듀파' '깊바협' '오징어' '협동' '블와둥']
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 0.49999999999999994
# Map: 블와둥, Score: 0.4999999999999998
# Map: 듀파, Score: -4.623038063478191e-16
# Recommended Maps: Index(['깊바협', '블와둥', '듀파'], dtype='object', name='map')
# ['깊바협', '블와둥', '듀파']

# %%
process_tsne(df)
process_tsne(df_cr)
# Out:
# Filtering out the top 99.9% outliers with distance greater than 2.0999318840500005
#       party_id      time  level  job    spec  map        date  valid  \
# 1307       245  오전 12:57  120.0   시프     NaN   산양  2024-12-24   True
# 2453       238   오후 9:48   96.0  용기사  3600.0   붉켄  2024-12-22   True
# 3335        29   오후 3:48  105.0   불독     NaN  NaN  2024-12-15  False
# 3850        25  오전 12:19  115.0  용기사     NaN   검켄  2024-12-16   True
# 4446       677   오전 1:39  144.0   썬콜     NaN  블와둥  2024-12-16   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  tsne_dim1  \
# 1307       False            NaN                NaN  2209.362009  15.634353
# 2453        True      37.500000          36.396941  3600.000000  37.259518
# 3335       False            NaN                NaN  2209.362009  -8.807467
# 3850       False      35.369864          35.369864  4142.848643  61.003422
# 4446       False       6.226383           6.226383   914.481994  11.609561
#
#       tsne_dim2  distance_to_nearest
# 1307   9.304316             2.379229
# 2453 -53.329742             2.280587
# 3335   2.738491             3.365109
# 3850 -34.797569             2.422559
# 4446  69.185684             2.206656
# Filtering out the top 99.9% outliers with distance greater than 1.4294674813949275
#      party_id     time  level    job  spec map        date valid  valid_spec  \
# 3485      124  오후 5:45  143.0  크루세이더  None  검켄  2024-12-15  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  tsne_dim1  tsne_dim2  \
# 3485      32.606408          32.606408  4636.234706  -6.148927   6.599022
#
#       distance_to_nearest
# 3485             1.526315

# %%
recommend_map_random_forest("크루세이더", 145)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 recommend_map_random_forest("크루세이더", 145)
#
# File /var/folders/mr/p421frt13mb2ycwc9z02q6x00000gn/T/ipykernel_12130/2575509407.py:77, in recommend_map_random_forest(job_input, level_input)
#      74 job_df = filter_data_by_job(job_input)
#      76 # Train the model for the selected job
# ---> 77 model, label_encoder, X = train_model_for_job(job_df)
#      79 # Get the recommended map and average spec
#      80 recommended_map, avg_spec = recommend_map(level_input, job_input, model, label_encoder, X)
#
# File /var/folders/mr/p421frt13mb2ycwc9z02q6x00000gn/T/ipykernel_12130/2575509407.py:25, in recommend_map_random_forest.<locals>.train_model_for_job(job_df)
#      23 def train_model_for_job(job_df):
#      24     # Label Encoding for the map column (since it's categorical)
# ---> 25     label_encoder = LabelEncoder()
#      26     job_df['map_encoded'] = label_encoder.fit_transform(job_df['map'])
#      28     # Handle missing values for the features
#
# NameError: name 'LabelEncoder' is not defined
