# %%
import os
os.chdir('/Users/lee/PythonProjects/mapleland/party')

# %%
# %run _01_data_loading.ipynb
# Out:
# Data saved as data/output/1219.csv
# Processed valid data saved as data/output/1219_processed.csv
# Data saved as data/output/1218.csv
# Processed valid data saved as data/output/1218_processed.csv
# Data saved as data/output/1220.csv
# Processed valid data saved as data/output/1220_processed.csv
# Data saved as data/output/1221.csv
# Processed valid data saved as data/output/1221_processed.csv
# Data saved as data/output/1222.csv
# Processed valid data saved as data/output/1222_processed.csv
# Data saved as data/output/1213.csv
# Processed valid data saved as data/output/1213_processed.csv
# Data saved as data/output/1212.csv
# Processed valid data saved as data/output/1212_processed.csv
# Data saved as data/output/1211.csv
# Processed valid data saved as data/output/1211_processed.csv
# Data saved as data/output/1215.csv
# Processed valid data saved as data/output/1215_processed.csv
# Data saved as data/output/1214.csv
# Processed valid data saved as data/output/1214_processed.csv
# Data saved as data/output/1216.csv
# Processed valid data saved as data/output/1216_processed.csv
# Data saved as data/output/1217.csv
# Processed valid data saved as data/output/1217_processed.csv
# Combined raw data saved as 'data/output/df.csv'
# Combined processed data saved as 'data/output/processed_df.csv'

# %%
df_cr = df[(df['job'] == '크루세이더')]
df_cr
# Out:
#      party_id      time level    job  spec   map        date  valid  \
# 10          4  오전 12:33   145  크루세이더  None   깊바협  2024-12-19   True
# 11          4  오전 12:33   158  크루세이더  None   깊바협  2024-12-19   True
# 15          7  오전 12:33   134  크루세이더  None  None  2024-12-19  False
# 58         33  오전 12:34   118  크루세이더  None    협동  2024-12-19   True
# 81         45  오전 12:35   126  크루세이더  4000  None  2024-12-19  False
# ...       ...       ...   ...    ...   ...   ...         ...    ...
# 3826      235   오후 1:56   117  크루세이더  None  None  2024-12-17  False
# 3833      242   오후 1:56   144  크루세이더  4800   블와둥  2024-12-17   True
# 3838      247   오후 1:57    97  크루세이더  3290    듀파  2024-12-17   True
# 3839      247   오후 1:57    97  크루세이더  None    듀파  2024-12-17   True
# 3866      290   오후 1:59   106  크루세이더  None   불어전  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled
# 10         False      32.403057          32.403057  4626.408003
# 11         False      32.403057          32.403057  5191.476268
# 15         False      32.403057          32.403057  4258.352203
# 58         False      32.403057          32.403057  3850.516325
# 81          True      31.746032          32.403057  4000.000000
# ...          ...            ...                ...          ...
# 3826       False      32.663128          32.663128  3851.921864
# 3833        True      33.333333          32.663128  4800.000000
# 3838        True      33.917526          32.663128  3290.000000
# 3839       False      32.663128          32.663128  3151.844467
# 3866       False      32.663128          32.663128  3467.787138
#
# [318 rows x 12 columns]

# %%
processed_df_cr = processed_df[(processed_df['job'] == '크루세이더')]
print(len(processed_df_cr))
processed_df_cr.head()
# Out:
# 51
#    party_id      time level    job  spec  map        date valid  valid_spec  \
# 9        55  오전 12:36    95  크루세이더  3100   듀파  2024-12-19  True        True
# 16       70  오전 12:37   157  크루세이더  5040  블와둥  2024-12-19  True        True
# 27      125   오후 9:07   143  크루세이더  4772  깊바협  2024-12-19  True        True
# 29      138   오후 9:08    88  크루세이더  2900   듀파  2024-12-19  True        True
# 34      170   오후 9:09   119  크루세이더  3800   협동  2024-12-19  True        True
#
#     spec_by_level  avg_spec_by_level  spec_filled
# 9       32.631579          32.403057       3100.0
# 16      32.101911          32.403057       5040.0
# 27      33.370629          32.403057       4772.0
# 29      32.954545          32.403057       2900.0
# 34      31.932773          32.403057       3800.0

# %%
# %run _02_eda.ipynb

map_dist(df)
map_dist(df_cr)
job_dist(df)
level_dist(df)
level_dist(df_cr)
level_dist_by_job(df)
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3878 entries, 0 to 3877
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   party_id           3878 non-null   int64
#  1   time               3878 non-null   object
#  2   level              3878 non-null   int64
#  3   job                3878 non-null   object
#  4   spec               527 non-null    float64
#  5   map                3475 non-null   object
#  6   date               3878 non-null   object
#  7   valid              3878 non-null   bool
#  8   valid_spec         3878 non-null   bool
#  9   spec_by_level      3577 non-null   float64
#  10  avg_spec_by_level  3577 non-null   float64
#  11  spec_filled        3577 non-null   float64
# dtypes: bool(2), float64(4), int64(2), object(4)
# memory usage: 310.7+ KB
# None
#
# Data Overview:
#    party_id      time  level  job   spec map        date  valid  valid_spec  \
# 0         1  오전 12:33     88   허밋    NaN  붉켄  2024-12-19   True       False
# 1         1  오전 12:33    101  레인저    NaN  붉켄  2024-12-19   True       False
# 2         2  오전 12:33     90   허밋    NaN  붉켄  2024-12-19   True       False
# 3         2  오전 12:33     99   허밋    NaN  붉켄  2024-12-19   True       False
# 4         2  오전 12:33    105   썬콜  650.0  붉켄  2024-12-19   True        True
#
#    spec_by_level  avg_spec_by_level  spec_filled
# 0      18.446821          18.446821  1666.881295
# 1      22.312474          22.312474  2203.531768
# 2      18.446821          18.446821  1696.659633
# 3      18.446821          18.446821  1807.640117
# 4       6.190476           6.212019   650.000000
#
# Map Frequency:
# map
# 협동     480
# 망용둥    418
# 불어전    415
# 듀파     360
# 블와둥    333
# 붉켄     248
# 깊바협    196
# 검켄     187
# 레와둥    160
# 산양     133
# 하둥     109
# 오징어     98
# 갈림길     74
# 와협      61
# 망둥쩔     56
# 푸켄      42
# 물어전     36
# 위둥      33
# 큰둥      19
# 남둥      17
# Name: count, dtype: int64
#
# Job Frequency:
# job
# 프리스트     994
# 허밋       789
# 썬콜       520
# 용기사      478
# 레인저      371
# 크루세이더    318
# 불독       144
# 저격수      131
# 나이트      113
# 시프        20
# Name: count, dtype: int64
#
# Level Statistics by Job:
#        count        mean        std   min     25%    50%    75%    max
# job
# 나이트    113.0  118.477876  18.957705  80.0  107.00  120.0  130.0  161.0
# 레인저    371.0  123.345013  18.393142  80.0  109.50  123.0  135.5  173.0
# 불독     144.0  131.625000  18.789550  87.0  117.00  130.0  146.5  173.0
# 시프      20.0  115.600000  13.386560  92.0  109.50  117.0  123.0  140.0
# 썬콜     520.0  123.576923  18.231487  80.0  109.75  124.0  137.0  169.0
# 용기사    478.0  128.926778  20.392708  81.0  115.00  129.0  145.0  175.0
# 저격수    131.0  118.282443  19.078088  83.0  102.50  119.0  133.0  160.0
# 크루세이더  318.0  127.701258  22.225587  82.0  112.00  127.0  144.0  175.0
# 프리스트   994.0  114.050302  18.369967  80.0   99.00  112.5  127.0  178.0
# 허밋     789.0  124.987326  21.542128  80.0  110.00  124.0  142.0  173.0

# %%
# %run _03_data_visualization.ipynb

job="크루세이더"
jobs=["크루세이더", "용기사"]
input_map="블와둥"
input_maps=["블와둥", "협동", "깊바협"]
start_level=120
end_level=160
input_level=145

#1 직업별 평균 스펙
# average_spec_by_job(df)
#2 맵별 직업 분포
# plot_job_frequency_by_map(df)
#3 특정 직업, 레벨(optional), 스펙_filled
plot_level_spec_with_regression(df, job)
plot_level_spec_with_regression(df, job, input_level=input_level, use_spec_filled=True)
#4 레벨+-5의 스펙 회귀
# plot_level_spec_with_regression_by_level(df, job, input_level)
#5 특정 직업의 레벨 별 맵 분포
plot_level_by_map_by_job(df, job)
#6 특정직업의 레벨별 사냥터 분포(5%+)
plot_level_distribution_by_job_and_map(df, job)
#7 특정 직업의 레벨별 맵 히트맵
plot_map_level_heatmap_for_job(df, job)
#8 특정직업의 레벨 범위별 사냥터 히트맵 
plot_map_frequency_by_level_range(df, job)
#9 맵별 스펙 기재 여부
visualize_spec_validity_by_map(df, job='all')
#10 직업별 스펙 기재 여부, job optional
visualize_spec_validity_by_jobs(df)
#11 날짜별 맵 사용 비율
# visualize_map_distribution_by_date(df)
visualize_map_distribution_by_date(df_cr)
#12 직업별 레벨(범위 설정 가능)당 스펙
# visualize_level_spec_comparison(df, jobs=None, start_level=None, end_level=None)
#13 직업별 레벨에 따른 스공과 맵, 회귀
# plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#14 맵 사용빈도 변화 추이
visualize_map_percentage_change(df_cr, input_maps[0])
visualize_map_percentage_change(df_cr, input_maps[1])
visualize_map_percentage_change(df_cr, input_maps[2])
# visualize_map_percentage_change(df_il, input_map)
#15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
plot_level_spec_distribution_of_job_and_map(df, input_maps[0], job, use_spec_filled=True)
plot_level_spec_distribution_of_job_and_map(df, input_maps[1], job, use_spec_filled=True)
plot_level_spec_distribution_of_job_and_map(df, input_maps[2], job, use_spec_filled=True)
#16 특정 직업의 맵별분포와 레벨, 스펙 회귀
plot_level_spec_distribution_of_job(df, job, use_spec_filled=False)

# %%
# %run _04_modeling.ipynb

recommend_map_knn(100, job, level_range=5)
recommend_map_svd(100, job, level_range=5)

recommend_map_knn(120, job, level_range=5)
recommend_map_svd(120, job, level_range=5)

recommend_map_knn(140, job, level_range=5)
recommend_map_svd(140, job, level_range=5)

# tsne_visualization(df)
process_tsne(df)

# tsne_visualization(df)
process_tsne(df_cr)
# Out:
# Similarity scores for recommended maps:
# Map: 오징어, Score: 15.391363481087813
# Map: 듀파, Score: 29.753991086617287
# Recommended Maps and Scores: ['오징어', '듀파']
# Unique maps after preprocessing:
# ['깊바협' '협동' '듀파' '오징어' '블와둥']
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 0.5000000000000004
# Map: 듀파, Score: 0.5000000000000001
# Map: 블와둥, Score: 8.673617379884035e-17
# Recommended Maps: Index(['깊바협', '듀파', '블와둥'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 5.244146000243943
# Map: 블와둥, Score: 6.5056907608793315
# Map: 오징어, Score: 12.732780202887877
# Recommended Maps and Scores: ['깊바협', '블와둥', '오징어']
# Unique maps after preprocessing:
# ['깊바협' '협동' '듀파' '오징어' '블와둥']
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 0.33333333333333387
# Map: 블와둥, Score: 0.3333333333333333
# Map: 듀파, Score: 0.33333333333333326
# Recommended Maps: Index(['깊바협', '블와둥', '듀파'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 산양, Score: 2.8828694311187064
# Map: 위둥, Score: 13.947295082762672
# Map: 불어전, Score: 14.681897314331225
# Recommended Maps and Scores: ['산양', '위둥', '불어전']
# Unique maps after preprocessing:
# ['깊바협' '협동' '듀파' '오징어' '블와둥']
# Similarity scores for recommended maps:
# Map: 깊바협, Score: 0.5000000000000004
# Map: 블와둥, Score: 0.5000000000000002
# Map: 듀파, Score: 8.239936510889834e-17
# Recommended Maps: Index(['깊바협', '블와둥', '듀파'], dtype='object', name='map')
# Filtering out the top 99.9% outliers with distance greater than 2.984221092457115
#       party_id      time  level  job  spec  map        date  valid  \
# 689         43  오전 12:38   93.0   시프   NaN   듀파  2024-12-20   True
# 2221        32   오후 3:48  139.0   시프   NaN   듀파  2024-12-15   True
# 2731        25  오전 12:19  115.0  용기사   NaN   검켄  2024-12-16   True
# 3709        89   오후 1:51  100.0   썬콜   NaN  망둥쩔  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  tsne_dim1  \
# 689        False            NaN                NaN  2196.513657  -6.941271
# 2221       False            NaN                NaN  2196.513657  -4.857016
# 2731       False      35.369864          35.369864  4141.678869  52.717438
# 3709       False       6.223686           6.223686   639.156473 -16.071749
#
#       tsne_dim2  distance_to_nearest
# 689  -21.776743             5.638562
# 2221 -40.501331             4.777196
# 2731 -36.997978             3.178506
# 3709  57.768784             3.913435
# Filtering out the top 99.9% outliers with distance greater than 2.2244698118719617
#      party_id     time  level    job  spec map        date valid  valid_spec  \
# 2028      482  오후 1:40  110.0  크루세이더  None  산양  2024-12-11  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  tsne_dim1  tsne_dim2  \
# 2028      32.361493          32.361493  3527.273149    5.07926   6.174625
#
#       distance_to_nearest
# 2028             2.288717
