# %%
import os
os.chdir('/Users/lee/PythonProjects/mapleland/party')

# %%
# %run _01_data_loading.ipynb
# Out:
# Data saved as data/output/1219.csv
# Processed valid data saved as data/output/1219_processed.csv
# Data saved as data/output/1218.csv
# Processed valid data saved as data/output/1218_processed.csv
# Data saved as data/output/1220.csv
# Processed valid data saved as data/output/1220_processed.csv
# Data saved as data/output/1221.csv
# Processed valid data saved as data/output/1221_processed.csv
# Data saved as data/output/1222.csv
# Processed valid data saved as data/output/1222_processed.csv
# Data saved as data/output/1213.csv
# Processed valid data saved as data/output/1213_processed.csv
# Data saved as data/output/1212.csv
# Processed valid data saved as data/output/1212_processed.csv
# Data saved as data/output/1211.csv
# Processed valid data saved as data/output/1211_processed.csv
# Data saved as data/output/1215.csv
# Processed valid data saved as data/output/1215_processed.csv
# Data saved as data/output/1214.csv
# Processed valid data saved as data/output/1214_processed.csv
# Data saved as data/output/1216.csv
# Processed valid data saved as data/output/1216_processed.csv
# Data saved as data/output/1217.csv
# Processed valid data saved as data/output/1217_processed.csv
# Combined raw data saved as 'data/output/df.csv'
# Combined processed data saved as 'data/output/processed_df.csv'

# %%
df
# Out:
#       party_id      time  level   job    spec  map        date  valid  \
# 0            1  오전 12:33   88.0    허밋     NaN   붉켄  2024-12-19   True
# 1            1  오전 12:33  101.0   레인저     NaN   붉켄  2024-12-19   True
# 2            2  오전 12:33   90.0    허밋     NaN   붉켄  2024-12-19   True
# 3            2  오전 12:33   99.0    허밋     NaN   붉켄  2024-12-19   True
# 4            2  오전 12:33  105.0    썬콜   650.0   붉켄  2024-12-19   True
# ...        ...       ...    ...   ...     ...  ...         ...    ...
# 3726       292   오후 1:59  143.0   용기사  5000.0  블와둥  2024-12-17   True
# 3727       297   오후 1:59  119.0  프리스트     NaN   검켄  2024-12-17   True
# 3728       297   오후 1:59  134.0  프리스트     NaN   검켄  2024-12-17   True
# 3729       300   오후 1:59  123.0  프리스트     NaN  NaN  2024-12-17  False
# 3730       301   오후 1:59  112.0    허밋     NaN   검켄  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  \
# 0          False      18.446821          18.446821  1650.914041
# 1          False      22.312474          22.312474  2306.272042
# 2          False      18.446821          18.446821  1694.803108
# 3          False      18.446821          18.446821  1868.749685
# 4           True       6.190476           6.212019   650.000000
# ...          ...            ...                ...          ...
# 3726        True      34.965035          35.282984  5000.000000
# 3727       False       6.320755           6.320755   750.810424
# 3728       False       6.320755           6.320755   871.141040
# 3729       False       6.320755           6.320755   793.527210
# 3730       False      18.956725          18.956725  2148.776396
#
#       spec_distance  avg_distance_per_job  tsne_dim1  tsne_dim2  \
# 0               NaN           2415.678179 -15.402051 -11.798494
# 1               NaN           2402.687526 -19.010410 -32.644947
# 2               NaN           2415.678179 -15.134619 -10.730488
# 3               NaN           2415.678179 -14.773553  -6.392847
# 4        643.787981            793.121314 -15.004476  47.066776
# ...             ...                   ...        ...        ...
# 3726    4964.717016           4940.217016  55.283279 -17.340635
# 3727            NaN            663.679245 -75.906525   4.331586
# 3728            NaN            663.679245 -74.987663  11.201365
# 3729            NaN            663.679245 -30.157093   6.657850
# 3730            NaN           2502.176609   6.118647   6.880669
#
#       distance_to_nearest
# 0                0.114575
# 1                0.026356
# 2                0.026599
# 3                0.021307
# 4                0.032572
# ...                   ...
# 3726             0.129477
# 3727             0.002051
# 3728             0.049510
# 3729             0.063934
# 3730             0.157667
#
# [3731 rows x 17 columns]

# %%
df_dk = df[(df['job'] == '용기사')]
df_dk
# Out:
#      party_id      time level  job  spec  map        date valid  valid_spec  \
# 16          8  오전 12:33    83  용기사  None   하둥  2024-12-19  True       False
# 18          9  오전 12:33   122  용기사  None   협동  2024-12-19  True       False
# 36         18  오전 12:34   124  용기사  4200  블와둥  2024-12-19  True        True
# 42         23  오전 12:34   126  용기사  None  블와둥  2024-12-19  True       False
# 44         24  오전 12:34   148  용기사  None   협동  2024-12-19  True       False
# ...       ...       ...   ...  ...   ...  ...         ...   ...         ...
# 3668      221   오후 1:55    97  용기사  None   하둥  2024-12-17  True       False
# 3688      246   오후 1:56   126  용기사  4100   듀파  2024-12-17  True        True
# 3695      255   오후 1:57   156  용기사  None  블와둥  2024-12-17  True       False
# 3707      263   오후 1:57   107  용기사  3400  불어전  2024-12-17  True        True
# 3726      292   오후 1:59   143  용기사  5000  블와둥  2024-12-17  True        True
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 16        34.726694          34.726694  2861.260209            NaN
# 18        34.726694          34.726694  4307.544745            NaN
# 36        33.870968          34.726694  4200.000000    4165.273306
# 42        34.726694          34.726694  4419.877739            NaN
# 44        34.726694          34.726694  5273.718570            NaN
# ...             ...                ...          ...            ...
# 3668      35.282984          35.282984  3425.802522            NaN
# 3688      32.539683          35.282984  4100.000000    4064.717016
# 3695      35.282984          35.282984  5522.410412            NaN
# 3707      31.775701          35.282984  3400.000000    3364.717016
# 3726      34.965035          35.282984  5000.000000    4964.717016
#
#       avg_distance_per_job
# 16             4411.364215
# 18             4411.364215
# 36             4411.364215
# 42             4411.364215
# 44             4411.364215
# ...                    ...
# 3668           4940.217016
# 3688           4940.217016
# 3695           4940.217016
# 3707           4940.217016
# 3726           4940.217016
#
# [453 rows x 14 columns]

# %%
processed_df_dk = processed_df[(processed_df['job'] == '용기사')]
print(len(processed_df_dk))
processed_df_dk.head()
# Out:
# 61
#    party_id      time level  job  spec  map        date valid  valid_spec  \
# 3        18  오전 12:34   124  용기사  4200  블와둥  2024-12-19  True        True
# 5        41  오전 12:35   127  용기사  4370  블와둥  2024-12-19  True        True
# 11       57  오전 12:36   119  용기사  4100   듀파  2024-12-19  True        True
# 13       67  오전 12:36   110  용기사  3700   하둥  2024-12-19  True        True
# 14       70  오전 12:37   157  용기사  5650  블와둥  2024-12-19  True        True
#
#     spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 3       33.870968          34.726694       4200.0    4165.273306
# 5       34.409449          34.726694       4370.0    4335.273306
# 11      34.453782          34.726694       4100.0    4065.273306
# 13      33.636364          34.726694       3700.0    3665.273306
# 14      35.987261          34.726694       5650.0    5615.273306
#
#     avg_distance_per_job
# 3            4411.364215
# 5            4411.364215
# 11           4411.364215
# 13           4411.364215
# 14           4411.364215

# %%
# %run _02_eda.ipynb

map_dist(df)
map_dist(df_dk)
job_dist(df)
level_dist(df)
level_dist(df_dk)
level_dist_by_job(df)
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3731 entries, 0 to 3730
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   party_id              3731 non-null   int64
#  1   time                  3731 non-null   object
#  2   level                 3731 non-null   int64
#  3   job                   3731 non-null   object
#  4   spec                  496 non-null    float64
#  5   map                   3351 non-null   object
#  6   date                  3731 non-null   object
#  7   valid                 3731 non-null   bool
#  8   valid_spec            3731 non-null   bool
#  9   spec_by_level         3430 non-null   float64
#  10  avg_spec_by_level     3430 non-null   float64
#  11  spec_filled           3430 non-null   float64
#  12  spec_distance         496 non-null    float64
#  13  avg_distance_per_job  3430 non-null   float64
# dtypes: bool(2), float64(6), int64(2), object(4)
# memory usage: 357.2+ KB
# None
#
# Data Overview:
#    party_id      time  level  job   spec map        date  valid  valid_spec  \
# 0         1  오전 12:33     88   허밋    NaN  붉켄  2024-12-19   True       False
# 1         1  오전 12:33    101  레인저    NaN  붉켄  2024-12-19   True       False
# 2         2  오전 12:33     90   허밋    NaN  붉켄  2024-12-19   True       False
# 3         2  오전 12:33     99   허밋    NaN  붉켄  2024-12-19   True       False
# 4         2  오전 12:33    105   썬콜  650.0  붉켄  2024-12-19   True        True
#
#    spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 0      18.446821          18.446821  1576.129861            NaN
# 1      22.312474          22.312474  2300.528287            NaN
# 2      18.446821          18.446821  1682.630869            NaN
# 3      18.446821          18.446821  1817.285133            NaN
# 4       6.190476           6.212019   650.000000     643.787981
#
#    avg_distance_per_job
# 0           2415.678179
# 1           2402.687526
# 2           2415.678179
# 3           2415.678179
# 4            793.121314
#
# Map Frequency:
# map
# 협동     447
# 불어전    409
# 망용둥    398
# 듀파     334
# 블와둥    328
# 붉켄     243
# 깊바협    196
# 검켄     185
# 레와둥    157
# 산양     128
# 하둥     106
# 오징어     98
# 갈림길     74
# 와협      56
# 망둥쩔     54
# 푸켄      40
# 물어전     34
# 위둥      29
# 큰둥      19
# 남둥      16
# Name: count, dtype: int64
#
# Job Frequency:
# job
# 프리스트     966
# 허밋       756
# 썬콜       497
# 용기사      453
# 레인저      354
# 크루세이더    312
# 불독       136
# 저격수      127
# 나이트      110
# 시프        20
# Name: count, dtype: int64
#
# Level Statistics by Job:
#        count        mean        std   min    25%    50%     75%    max
# job
# 나이트    110.0  118.445455  19.156328  80.0  107.0  120.0  130.75  161.0
# 레인저    354.0  123.073446  18.340507  80.0  109.0  123.0  134.75  173.0
# 불독     136.0  132.066176  19.120748  87.0  117.0  130.5  149.00  173.0
# 시프      20.0  115.600000  13.386560  92.0  109.5  117.0  123.00  140.0
# 썬콜     497.0  123.734406  18.242594  80.0  110.0  124.0  138.00  169.0
# 용기사    453.0  129.403974  20.406547  81.0  115.0  129.0  146.00  175.0
# 저격수    127.0  118.244094  19.284304  83.0  102.5  117.0  133.00  160.0
# 크루세이더  312.0  127.830128  22.289241  82.0  112.0  127.0  144.00  175.0
# 프리스트   966.0  114.265010  18.407032  80.0   99.0  113.0  128.00  178.0
# 허밋     756.0  125.093915  21.725205  80.0  109.0  124.0  142.00  173.0

# %%
# %run _03_data_visualization.ipynb

job="용기사"
jobs=["용기사", "크루세이더"]
input_map="블와둥"
input_maps=["블와둥", "협동", "깊바협"]
start_level=120
end_level=160
input_level=145

#1 직업별 평균 스펙
# average_spec_by_job(df)
#2 맵별 직업 분포
# plot_job_frequency_by_map(df)
#3 특정 직업, 레벨(optional), 스펙_filled
plot_level_spec_with_regression(df, job)
plot_level_spec_with_regression(df, job, input_level=input_level, use_spec_filled=True)
#4 레벨+-5의 스펙 회귀
# plot_level_spec_with_regression_by_level(df, job, input_level)
#5 특정 직업의 레벨 별 맵 분포
plot_level_by_map_by_job(df, job)
#6 특정직업의 레벨별 사냥터 분포(5%+)
plot_level_distribution_by_job_and_map(df, job)
#7 특정 직업의 레벨별 맵 히트맵
plot_map_level_heatmap_for_job(df, job)
#8 특정직업의 레벨 범위별 사냥터 히트맵 
plot_map_frequency_by_level_range(df, job)
#9 맵별 스펙 기재 여부
visualize_spec_validity_by_map(df, job='all')
visualize_spec_validity_by_map(df, job=job)
#10 직업별 스펙 기재 여부, job optional
visualize_spec_validity_by_jobs(df, jobs=None)
#11 날짜별 맵 사용 비율
# visualize_map_distribution_by_date(df)
# visualize_map_distribution_by_date(df_il)
#12 직업별 레벨(범위 설정 가능)당 스펙
# visualize_level_spec_comparison(df, jobs=None, start_level=None, end_level=None)
#13 직업별 레벨에 따른 스공과 맵, 회귀
# plot_combined_scatter_with_regression(df_il, start_level=None, end_level=None, maps=None)
#14 맵 사용빈도 변화 추이
visualize_map_percentage_change(df_dk, input_map)
# visualize_map_percentage_change(df_il, input_map)
#15 특정 직업의 맵 레벨과 스펙에 따른 분포도 확인
plot_level_spec_distribution_of_job_and_map(df, input_map, job, use_spec_filled=True)
#16 특정 직업의 맵별분포와 레벨, 스펙 회귀
plot_level_spec_distribution_of_job(df, job)

# %%
# %run _04_modeling.ipynb

recommend_map_knn(100, job, level_range=5)
recommend_map_svd(100, job, level_range=5)

recommend_map_knn(120, job, level_range=5)
recommend_map_svd(120, job, level_range=5)

recommend_map_knn(140, job, level_range=5)
recommend_map_svd(140, job, level_range=5)

process_tsne(df)
process_tsne(df_dk)
# Out:
# Similarity scores for recommended maps:
# Map: 하둥, Score: 4.4358403518407306
# Recommended Maps and Scores: ['하둥']
# Unique maps after preprocessing:
# ['하둥' '협동' '블와둥' '산양' '듀파']
# Similarity scores for recommended maps:
# Map: 블와둥, Score: 0.49999999999999994
# Map: 듀파, Score: 0.49999999999999967
# Map: 산양, Score: 1.1058862159352145e-16
# Recommended Maps: Index(['블와둥', '듀파', '산양'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 협동, Score: 4.3223244513484715
# Map: 블와둥, Score: 4.582225146772157
# Map: 하둥, Score: 10.892211260089828
# Recommended Maps and Scores: ['협동', '블와둥', '하둥']
# Unique maps after preprocessing:
# ['하둥' '협동' '블와둥' '산양' '듀파']
# Similarity scores for recommended maps:
# Map: 산양, Score: 0.3333333333333334
# Map: 블와둥, Score: 0.3333333333333333
# Map: 듀파, Score: 0.33333333333333315
# Recommended Maps: Index(['산양', '블와둥', '듀파'], dtype='object', name='map')
# Similarity scores for recommended maps:
# Map: 블와둥, Score: 10.569279037437376
# Map: 산양, Score: 10.910712945097849
# Recommended Maps and Scores: ['블와둥', '산양']
# Unique maps after preprocessing:
# ['하둥' '협동' '블와둥' '산양' '듀파']
# Similarity scores for recommended maps:
# Map: 블와둥, Score: 0.5000000000000002
# Map: 산양, Score: 0.5000000000000001
# Map: 듀파, Score: -1.3140530330524314e-16
# Recommended Maps: Index(['블와둥', '산양', '듀파'], dtype='object', name='map')
# Filtering out the top 99.9% outliers with distance greater than 2.9968340790530785
#       party_id      time  level  job  spec  map        date  valid  \
# 689         43  오전 12:38   93.0   시프   NaN   듀파  2024-12-20   True
# 2074        32   오후 3:48  139.0   시프   NaN   듀파  2024-12-15   True
# 2584        25  오전 12:19  115.0  용기사   NaN   검켄  2024-12-16   True
# 3562        89   오후 1:51  100.0   썬콜   NaN  망둥쩔  2024-12-17   True
#
#       valid_spec  spec_by_level  avg_spec_by_level  spec_filled  \
# 689        False            NaN                NaN  2194.998481
# 2074       False            NaN                NaN  2194.998481
# 2584       False      35.369864          35.369864  4077.629499
# 3562       False       6.223686           6.223686   610.532827
#
#       spec_distance  avg_distance_per_job  tsne_dim1  tsne_dim2  \
# 689             NaN                   NaN  -5.711728 -18.838549
# 2074            NaN                   NaN  -4.354968 -37.870117
# 2584            NaN           4700.830136  44.713959 -37.871521
# 3562            NaN            887.776314 -15.137711  53.065243
#
#       distance_to_nearest
# 689              5.880593
# 2074             4.684558
# 2584             3.408863
# 3562             3.023279
# Filtering out the top 99.9% outliers with distance greater than 3.471868381135091
#      party_id      time  level  job  spec map        date valid  valid_spec  \
# 2584       25  오전 12:19  115.0  용기사  None  검켄  2024-12-16  True       False
#
#       spec_by_level  avg_spec_by_level  spec_filled  spec_distance  \
# 2584      35.369864          35.369864  3954.619873            NaN
#
#       avg_distance_per_job  tsne_dim1  tsne_dim2  distance_to_nearest
# 2584           4700.830136 -17.345263  -2.818969             3.754816
